# %%
from pattern import web
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

url = ["http://www.aishub.net/stations?page=" + str(i) for i in range(1, 16)]

def getTable(html):
    """
    Function
    --------
    Scans html for data table and returns as a dataframe.
    
    Parameters
    ----------
    html : URL address of data table
    
    Returns
    -------
    Full dataframe
    """
    
    #Nested functions
    def extractfromi(element):
        if '<i' in str(element):
            return web.Element(element)('i')[0].attrs['title']
        else:
            return element
        
    def extractfromspan(element):
        if '<span' in str(element):
            span = web.Element(element)('span')[0]
            if span.content == '': #Get tile
                return span.attrs['title']
            else:
                return span.content
        else:
            element
        
    def extractfroma(element):
        if '<a ' in str(element):
            a = web.Element(element)('a')[0]
            if a.content == '': #Get tile
                try:
                    return a.attrs['title']
                except:
                    return None
            else:
                return a.content
        else:
            return element
        
    
    #Extract all data from webpage
    u = web.URL(html)
    code = u.download(cached=True)
    dom = web.Element(code)
    
    #get list of headers of data columns
    table_header = dom('tr')[0]
    headers = [table_header('th a')[i].content for i in range(len(table_header('th a')))]
    headers.append('Source')
    
    #Define the result as a dataframe containing all named columns
    result = pd.DataFrame({k: [] for k in headers})
    
    #Get table data and append to dataframe
    table_data = dom('tbody tr')
    for i in range(len(table_data)):
        row = table_data[i]
        tds = row('td')
        cells = [tds[j].content for j in range(len(tds))]
        
        #Make table readable for user
        for k in range(len(cells)):
            if "<i " in str(cells[k]):
                cells[k] = extractfromi(cells[k])
            elif "<span" in str(cells[k]):
                cells[k] = extractfromspan(cells[k])
            elif "<a " in str(cells[k]):
                cells[k] = extractfroma(cells[k])
        
        result = result.append(pd.Series(cells, index=headers), ignore_index=True)
    
    return result

station_list = pd.DataFrame()
for u in url:
    station_list = station_list.append(getTable(u))
station_list = station_list.set_index('ID')

station_list
# Out:
#                     Status Uptime                   Country  \
# ID
# 2418                Online  100 %                    Angola
# 2766                Online   97 %                    Angola
# 2995                Online  100 %                 Australia
# 2502                Online  100 %                 Australia
# 2508                Online  100 %                 Australia
# 2740                Online  100 %                 Australia
# 2556                Online   99 %                 Australia
# 2637                Online   91 %                 Australia
# 2936                Online   99 %                 Australia
# 2465                Online   98 %                 Australia
# 2864                Online  100 %                 Australia
# 2234                Online  100 %                 Australia
# 2360                Online  100 %                 Australia
# 2070                Online  100 %                 Australia
# 2675                Online  100 %                 Australia
# 3292                Online   91 %                 Australia
# 2701                Online  100 %                 Australia
# 2520                Online  100 %                   Austria
# 2798                Online  100 %                   Austria
# 3258                Online   47 %                  Barbados
# 2145                Online  100 %                   Belgium
# 2713  Offline > 10 minutes   51 %                   Belgium
# 2265                Online  100 %                   Belgium
# 2515                Online  100 %                   Belgium
# 2292                Online  100 %                   Belgium
# 3249                Online   95 %                   Belgium
# 3359                Online   89 %                   Belgium
# 2404                Online  100 %                   Belgium
# 2724                Online   95 %                   Belgium
# 2300                Online  100 %                   Belgium
# ...                    ...    ...                       ...
# 2944                  Dead    0 %  United States of America
# 2891  Offline > 10 minutes    2 %  United States of America
# 3221                Online  100 %  United States of America
# 2349                Online   90 %  United States of America
# 2657  Offline > 10 minutes   64 %  United States of America
# 2727    Offline > 24 hours   18 %  United States of America
# 2056                Online  100 %  United States of America
# 2229  Offline > 10 minutes   43 %  United States of America
# 2247                Online  100 %  United States of America
# 2495                Online  100 %  United States of America
# 2277                Online  100 %  United States of America
# 2833                Online  100 %  United States of America
# 3342                Online   95 %  United States of America
# 2646                Online   99 %  United States of America
# 2184                Online  100 %  United States of America
# 2023                Online  100 %  United States of America
# 2035                Online  100 %  United States of America
# 3231                Online  100 %  United States of America
# 3380                Online    7 %  United States of America
# 2466                Online   97 %  United States of America
# 2650                Online   98 %  United States of America
# 2071                Online   93 %  United States of America
# 2048                Online   45 %  United States of America
# 2656                Online   71 %                   Unknown
# 3146  Offline > 10 minutes   35 %                   Unknown
# 2992                Online  100 %                   Unknown
# 2688    Offline > 24 hours   21 %                   Unknown
# 2389                Online  100 %                   Uruguay
# 3314                Online  100 %                  Viet Nam
# 2040                Online  100 %                  Viet Nam
#
#                       Location Ships Distinct              Source
# ID
# 2418                     Zaire    39       38                None
# 2766                     Zaire     9        9                None
# 2995                  Kingston    10        8                None
# 2502               Scarborough     4        0                None
# 2508             Port Stephens    27       10                None
# 2740                    Coogee    23        0                None
# 2556                  Franklin     5        5                None
# 2637                 Devonport     4        4                None
# 2936                 Kettering    14       12                None
# 2465                    Darwin    55       55                None
# 2864                Morayfield    24       20                None
# 2234    Mt Arthur (N.Tasmania)    12       12                None
# 2360              Port Hedland   130      126                None
# 2070           Nelson Bay, NSW    25        8                None
# 2675                    Sydney    20       20                None
# 3292        Oakleigh, Victoria     1        1             SARCNET
# 2701                  O'Connor    71       48                None
# 2520                    Vienna    11        0                None
# 2798                      Linz    45       45                None
# 3258                 St. James     6        6                None
# 2145                  Antwerp2   417       34  Tresco Engineering
# 2713                    Leuven     0        0                None
# 2265                   Antwerp   378        0    www.canaleye.com
# 2515                 Antwerpen   741       81    www.canaleye.com
# 2292                      Gent   380       69                None
# 3249                   Antwerp    81        0                None
# 3359                   Schoten    18        1                None
# 2404                    Bruges   116       36            dotOcean
# 2724                     Ghent     3        0                None
# 2300                   Schilde   236       23     www.vemasys.com
# ...                        ...   ...      ...                 ...
# 2944                   Seattle     0        0                None
# 2891                 Melbourne     0        0                None
# 3221           Mill Valley, CA    32        1                None
# 2349                  Portland    65       50                None
# 2657                     Niles     0        0                None
# 2727                Washingotn     0        0                None
# 2056               New Orleans   105      104                None
# 2229                  New York     0        0                None
# 2247        Hanover, Maryland     46       30                None
# 2495                Duluth, MN    13       13                None
# 2277     Dania Beach - Florida   208       21                None
# 2833                    Groton     7        0                None
# 3342             San Francisco    98        3                None
# 2646             Arkwright, NY     2        2                None
# 2184                  Beaufort    40       40                None
# 2023  Baltimore MD, Wilmington    28        8                None
# 2035                   Seattle   324       74         Shine Micro
# 3231    Baton Rouge, Louisiana    53       53                None
# 3380                   Brielle     2        2                None
# 2466                Callao, VA     1        1                None
# 2650        Sabine Pass, Texas   104        5                None
# 2071       Fort Lauderdale, Fl   441        0                None
# 2048              Adak, Alaska     6        6                None
# 2656                  Cagliari    21       21                None
# 3146                    At Sea     0        0             Sea Jay
# 2992                    At Sea    37        2                None
# 2688            Mobile Station     0        0                None
# 2389                Montevideo    30       30                None
# 3314                     Hanoi    45       45                None
# 2040                      HCMC    21       21                None
#
# [744 rows x 7 columns]

# %%
import geopandas as gpd

from numpy import format_float_scientific as ffs

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world = world.rename(columns={'name': 'Country'})

world = world.set_index('Country')
world.plot()

# %%
def mapByDistinct(stations):
    """
    Function
    --------
    Maps each country by how many of its distint ships are active
    
    Parameters
    ----------
    stations: dataframe of each station on record
    
    Returns
    -------
    Nothing
    """
    stations = stations[(stations.Status == "Online") & (stations.Country != 'Unknown')]
    stations.Country = stations.Country.replace("Viet Nam", "Vietnam").replace("Saint Martin (FR)", "France").replace("Taiwan (Province of China)", "Taiwan").replace("Russian Federation", "Russia")
    stations = stations.set_index(['Country','Source'])
    distinct_total = stations.Distinct.astype(int).sum(level="Country")
    
    #append to world
    global world
    world["Ship_circulation_est"] = distinct_total
    
    #plot result
    result = world.plot(column='Ship_circulation_est', 
                        legend=True,
                        legend_kwds={'label': 'Active ships per country',
                                     'orientation': 'horizontal'},
                        missing_kwds={'color':'lightgrey'})
    plt.title('MAP: AIS')
    plt.savefig('shipsPerCountry.png')
    
    return result

ships_per_Country = mapByDistinct(station_list)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
#Now less see the amount of active ships per 1000000 persons for each country
world["Ships_per_1e6"] = (world.Ship_circulation_est / world.pop_est) * 1e6


ships_per_1e6 = world.plot(column='Ships_per_1e6', 
                           legend=True,
                           legend_kwds={'label': 'Active ships relative to million persons',
                                        'orientation': 'horizontal'},
                           missing_kwds={'color': 'lightgray'})
plt.savefig('shipsPer1e6.png')

# %%
from scipy.special import erf
def GaussianProb():
    """
    Function
    --------
    Works out gaussian porobability that ship belongs to specific demographic. Adds to dataframe
    
    Parameters
    ----------
    None
    
    Returns
    -------
    None
    """
    cdf = lambda x, mu, sig: 0.5 * (1 + erf((x - mu) / (sig * np.sqrt(2))))
    
    global world
    world["CDF"] = cdf(world.Ship_circulation_est, world.Ship_circulation_est.mean(), world.Ship_circulation_est.std())
    
    #If NaN assume zero
    world.CDF = world.CDF.fillna(float(0))
    
GaussianProb()

# %%
fig, ax = plt.subplots(figsize = (20, 20))
ships_cdf = world.plot(column='CDF', 
                           legend=True,
                           legend_kwds={'label': 'Likleyhood active ship belongs to country',
                                        'orientation': 'horizontal'},
                       ax=ax)
plt.title('MAP: CDF')
plt.savefig('shipsCDF.png')

# %%
ports = pd.DataFrame({'Country': station_list.Country, 'Location': station_list.Location}).drop_duplicates()

# %%
#We will have to find a way of adding geometric loction to each station
#First less add a column to ports labeled geometry and set each entry to None
ports["Longitude"] = [None for i in range(ports.shape[0])]
ports["Latitude"] = [None for i in range(ports.shape[0])]
cities = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))
ports
# Out:
#                        Country                  Location Longitude Latitude
# ID
# 2418                    Angola                     Zaire      None     None
# 2995                 Australia                  Kingston      None     None
# 2502                 Australia               Scarborough      None     None
# 2508                 Australia             Port Stephens      None     None
# 2740                 Australia                    Coogee      None     None
# 2556                 Australia                  Franklin      None     None
# 2637                 Australia                 Devonport      None     None
# 2936                 Australia                 Kettering      None     None
# 2465                 Australia                    Darwin      None     None
# 2864                 Australia                Morayfield      None     None
# 2234                 Australia    Mt Arthur (N.Tasmania)      None     None
# 2360                 Australia              Port Hedland      None     None
# 2070                 Australia           Nelson Bay, NSW      None     None
# 2675                 Australia                    Sydney      None     None
# 3292                 Australia        Oakleigh, Victoria      None     None
# 2701                 Australia                  O'Connor      None     None
# 2520                   Austria                    Vienna      None     None
# 2798                   Austria                      Linz      None     None
# 3258                  Barbados                 St. James      None     None
# 2145                   Belgium                  Antwerp2      None     None
# 2713                   Belgium                    Leuven      None     None
# 2265                   Belgium                   Antwerp      None     None
# 2515                   Belgium                 Antwerpen      None     None
# 2292                   Belgium                      Gent      None     None
# 3359                   Belgium                   Schoten      None     None
# 2404                   Belgium                    Bruges      None     None
# 2724                   Belgium                     Ghent      None     None
# 2300                   Belgium                   Schilde      None     None
# 2709                   Belgium   Watervliet, St Laureins      None     None
# 2061                   Belgium                    Ostend      None     None
# ...                        ...                       ...       ...      ...
# 3045  United States of America                  New York      None     None
# 3001  United States of America                  Brooklyn      None     None
# 2172  United States of America                Navarre FL      None     None
# 3253  United States of America      Berkeley, California      None     None
# 2638  United States of America            Baldwin Harbor      None     None
# 2891  United States of America                 Melbourne      None     None
# 3221  United States of America           Mill Valley, CA      None     None
# 2349  United States of America                  Portland      None     None
# 2657  United States of America                     Niles      None     None
# 2727  United States of America                Washingotn      None     None
# 2056  United States of America               New Orleans      None     None
# 2247  United States of America        Hanover, Maryland       None     None
# 2495  United States of America                Duluth, MN      None     None
# 2277  United States of America     Dania Beach - Florida      None     None
# 2833  United States of America                    Groton      None     None
# 2646  United States of America             Arkwright, NY      None     None
# 2184  United States of America                  Beaufort      None     None
# 2023  United States of America  Baltimore MD, Wilmington      None     None
# 3231  United States of America    Baton Rouge, Louisiana      None     None
# 3380  United States of America                   Brielle      None     None
# 2466  United States of America                Callao, VA      None     None
# 2650  United States of America        Sabine Pass, Texas      None     None
# 2071  United States of America       Fort Lauderdale, Fl      None     None
# 2048  United States of America              Adak, Alaska      None     None
# 2656                   Unknown                  Cagliari      None     None
# 3146                   Unknown                    At Sea      None     None
# 2688                   Unknown            Mobile Station      None     None
# 2389                   Uruguay                Montevideo      None     None
# 3314                  Viet Nam                     Hanoi      None     None
# 2040                  Viet Nam                      HCMC      None     None
#
# [586 rows x 4 columns]

# %%
import wikipedia as wiki
def getGeometry(station):
    """
    Function
    --------
    Gets geometric location for each port, by mining wikipedia.
    
    Parameters
    ----------
    station: Entry in dataframe ports
    
    Returns
    -------
    geometry: estimated location in float form
    """
    coords = None
    i = 0
    engine = wiki.search(station.Location + ', ' + station.Country)
    while i < len(engine):
        try:
            page = wiki.page(engine[i])
            coords = page.coordinates
            break
        except wiki.exceptions.DisambiguationError as dmbError:
            engine = wiki.search(station.Location + ', ' + station.Country + ', port')
        except:
            coords = None
        i = i + 1
    
    try:
        station.Longitude = float(coords[0])
        station.Latitude = float(coords[1])
    except:
        station.Longitude = float(np.nan)
        station.Latitude = float(np.nan)
        
    return station

j = 0
while j < 586:
    ports.iloc[j, :] = getGeometry(ports.iloc[j, :])
    j = j + 1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# C:\ProgramData\Anaconda3\lib\site-packages\wikipedia\wikipedia.py:389: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file C:\ProgramData\Anaconda3\lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')

# %%
ports
# Out:
#                        Country                  Location Longitude Latitude
# ID
# 2418                    Angola                     Zaire  -6.26667  14.2333
# 2995                 Australia                  Kingston  -35.3156  149.144
# 2502                 Australia               Scarborough  -31.8942  115.764
# 2508                 Australia             Port Stephens    -32.75  151.917
# 2740                 Australia                    Coogee   -32.119  115.766
# 2556                 Australia                  Franklin       -25      133
# 2637                 Australia                 Devonport  -41.1806  146.346
# 2936                 Australia                 Kettering  -43.1167  147.267
# 2465                 Australia                    Darwin  -12.4381  130.841
# 2864                 Australia                Morayfield  -27.1053  152.947
# 2234                 Australia    Mt Arthur (N.Tasmania)  -42.9047  147.323
# 2360                 Australia              Port Hedland    -20.31  118.601
# 2070                 Australia           Nelson Bay, NSW   -32.715  152.151
# 2675                 Australia                    Sydney   -33.865  151.209
# 3292                 Australia        Oakleigh, Victoria   -37.913  145.102
# 2701                 Australia                  O'Connor    -43.15   147.85
# 2520                   Austria                    Vienna        16      108
# 2798                   Austria                      Linz      48.3  14.2833
# 3258                  Barbados                 St. James   13.2167 -59.6167
# 2145                   Belgium                  Antwerp2   51.2178  4.40028
# 2713                   Belgium                    Leuven   50.8833      4.7
# 2265                   Belgium                   Antwerp   51.2178  4.40028
# 2515                   Belgium                 Antwerpen   51.2178  4.40028
# 2292                   Belgium                      Gent   51.0536  3.72528
# 3359                   Belgium                   Schoten     51.25      4.5
# 2404                   Belgium                    Bruges   51.2167  3.23333
# 2724                   Belgium                     Ghent   51.0536  3.72528
# 2300                   Belgium                   Schilde   51.2333  4.56667
# 2709                   Belgium   Watervliet, St Laureins       NaN      NaN
# 2061                   Belgium                    Ostend   51.2333  2.91667
# ...                        ...                       ...       ...      ...
# 3045  United States of America                  New York   40.7127  -74.006
# 3001  United States of America                  Brooklyn   40.6603 -74.0044
# 2172  United States of America                Navarre FL    30.401  -86.863
# 3253  United States of America      Berkeley, California   37.8717 -122.273
# 2638  United States of America            Baldwin Harbor   40.6339 -73.6039
# 2891  United States of America                 Melbourne   38.8906 -77.0044
# 3221  United States of America           Mill Valley, CA   37.9061 -122.545
# 2349  United States of America                  Portland        40     -100
# 2657  United States of America                     Niles   41.1853 -80.7572
# 2727  United States of America                Washingotn   38.9047 -77.0164
# 2056  United States of America               New Orleans     29.95   -90.08
# 2247  United States of America        Hanover, Maryland    39.1928 -76.7242
# 2495  United States of America                Duluth, MN   46.7869 -92.0982
# 2277  United States of America     Dania Beach - Florida   26.1935 -80.4767
# 2833  United States of America                    Groton   41.3485 -72.0775
# 2646  United States of America             Arkwright, NY        55       -3
# 2184  United States of America                  Beaufort   32.4497 -80.6797
# 2023  United States of America  Baltimore MD, Wilmington   39.7458 -75.5467
# 3231  United States of America    Baton Rouge, Louisiana   30.4475 -91.1786
# 3380  United States of America                   Brielle   40.1051 -74.0628
# 2466  United States of America                Callao, VA     37.86   -76.38
# 2650  United States of America        Sabine Pass, Texas   29.7264 -93.8633
# 2071  United States of America       Fort Lauderdale, Fl   26.1333   -80.15
# 2048  United States of America              Adak, Alaska    51.872 -176.636
# 2656                   Unknown                  Cagliari   39.2278  9.11111
# 3146                   Unknown                    At Sea      65.5     37.5
# 2688                   Unknown            Mobile Station       NaN      NaN
# 2389                   Uruguay                Montevideo  -34.8836 -56.1819
# 3314                  Viet Nam                     Hanoi   21.0283  105.854
# 2040                  Viet Nam                      HCMC        16      108
#
# [586 rows x 4 columns]

# %%
#Drop nan items from Dataframe
ports = ports.dropna()
ports
# Out:
#                        Country                  Location Longitude Latitude
# ID
# 2418                    Angola                     Zaire  -6.26667  14.2333
# 2995                 Australia                  Kingston  -35.3156  149.144
# 2502                 Australia               Scarborough  -31.8942  115.764
# 2508                 Australia             Port Stephens    -32.75  151.917
# 2740                 Australia                    Coogee   -32.119  115.766
# 2556                 Australia                  Franklin       -25      133
# 2637                 Australia                 Devonport  -41.1806  146.346
# 2936                 Australia                 Kettering  -43.1167  147.267
# 2465                 Australia                    Darwin  -12.4381  130.841
# 2864                 Australia                Morayfield  -27.1053  152.947
# 2234                 Australia    Mt Arthur (N.Tasmania)  -42.9047  147.323
# 2360                 Australia              Port Hedland    -20.31  118.601
# 2070                 Australia           Nelson Bay, NSW   -32.715  152.151
# 2675                 Australia                    Sydney   -33.865  151.209
# 3292                 Australia        Oakleigh, Victoria   -37.913  145.102
# 2701                 Australia                  O'Connor    -43.15   147.85
# 2520                   Austria                    Vienna        16      108
# 2798                   Austria                      Linz      48.3  14.2833
# 3258                  Barbados                 St. James   13.2167 -59.6167
# 2145                   Belgium                  Antwerp2   51.2178  4.40028
# 2713                   Belgium                    Leuven   50.8833      4.7
# 2265                   Belgium                   Antwerp   51.2178  4.40028
# 2515                   Belgium                 Antwerpen   51.2178  4.40028
# 2292                   Belgium                      Gent   51.0536  3.72528
# 3359                   Belgium                   Schoten     51.25      4.5
# 2404                   Belgium                    Bruges   51.2167  3.23333
# 2724                   Belgium                     Ghent   51.0536  3.72528
# 2300                   Belgium                   Schilde   51.2333  4.56667
# 2061                   Belgium                    Ostend   51.2333  2.91667
# 3283                   Belgium                 Diksmuide   51.0468   2.8436
# ...                        ...                       ...       ...      ...
# 2523  United States of America           West Palm Beach    26.715 -80.0394
# 3045  United States of America                  New York   40.7127  -74.006
# 3001  United States of America                  Brooklyn   40.6603 -74.0044
# 2172  United States of America                Navarre FL    30.401  -86.863
# 3253  United States of America      Berkeley, California   37.8717 -122.273
# 2638  United States of America            Baldwin Harbor   40.6339 -73.6039
# 2891  United States of America                 Melbourne   38.8906 -77.0044
# 3221  United States of America           Mill Valley, CA   37.9061 -122.545
# 2349  United States of America                  Portland        40     -100
# 2657  United States of America                     Niles   41.1853 -80.7572
# 2727  United States of America                Washingotn   38.9047 -77.0164
# 2056  United States of America               New Orleans     29.95   -90.08
# 2247  United States of America        Hanover, Maryland    39.1928 -76.7242
# 2495  United States of America                Duluth, MN   46.7869 -92.0982
# 2277  United States of America     Dania Beach - Florida   26.1935 -80.4767
# 2833  United States of America                    Groton   41.3485 -72.0775
# 2646  United States of America             Arkwright, NY        55       -3
# 2184  United States of America                  Beaufort   32.4497 -80.6797
# 2023  United States of America  Baltimore MD, Wilmington   39.7458 -75.5467
# 3231  United States of America    Baton Rouge, Louisiana   30.4475 -91.1786
# 3380  United States of America                   Brielle   40.1051 -74.0628
# 2466  United States of America                Callao, VA     37.86   -76.38
# 2650  United States of America        Sabine Pass, Texas   29.7264 -93.8633
# 2071  United States of America       Fort Lauderdale, Fl   26.1333   -80.15
# 2048  United States of America              Adak, Alaska    51.872 -176.636
# 2656                   Unknown                  Cagliari   39.2278  9.11111
# 3146                   Unknown                    At Sea      65.5     37.5
# 2389                   Uruguay                Montevideo  -34.8836 -56.1819
# 3314                  Viet Nam                     Hanoi   21.0283  105.854
# 2040                  Viet Nam                      HCMC        16      108
#
# [566 rows x 4 columns]

# %%
#Convert pors to geoDataFrame
geoPorts = gpd.GeoDataFrame(ports, geometry=gpd.points_from_xy(ports.Latitude, ports.Longitude))

# %%
fig, ax = plt.subplots(figsize = (20, 20))
world.plot(column='CDF', 
           legend=True,
           legend_kwds={'label': 'Likleyhood active ship belongs to country',
                        'orientation': 'horizontal'},
           ax=ax)
geoPorts.plot(ax=ax, label='AIS stations', legend='True')
plt.title('MAP: AIS stations')
plt.legend()
plt.savefig('AISnetwork.png')

# %%
def nearestStation(start, dest, location):
    """
    Function
    --------
    Function will take a coordinate pair, start 
    country and destination country, then return the nearest 
    station. Assume this is in the case of a lost and 
    stranded ship that is in need of finding its way back. We 
    will try to find this through checking the 2 norm.
    
    Parameters
    ----------
    start: Country the ship left
    dest: Country the ship wants to get to
    location: Coordinates of ship
    
    Returns
    -------
    Station: Location the ship needs to go to to get back on 
    course.
    """
    
    global world, geoPorts
    origin = world[world.index == start].geometry.bounds
    end = world[world.index == dest].geometry.bounds
    
    #Assume longest route to get vector direction in unit form
    vector = {'x': end.maxx[0] - origin.minx[0], 'y': end.maxy[0] - origin.miny[0]}
    vector = {'x': vector['x'] / np.sqrt(pow(vector['x'], 2) + pow(vector['y'], 2)), 
          'y': vector['y'] / np.sqrt(pow(vector['x'], 2) + pow(vector['y'], 2))}
    
    locV = {'x': location[0], 'y': location[0]}
    
    station = geoPorts.iloc[0, :]
    #First try and find if there are any stations between location and destination
    possibleStations = geoPorts[(geoPorts.Longitude > min(end.maxx[0], location[0])) & 
                                (geoPorts.Longitude < max(end.maxx[0], location[0])) &
                                (geoPorts.Latitude > min(end.maxy[0], location[0])) &
                                (geoPorts.Latitude < max(end.maxy[0], location[0]))]
    #If empty check any towards start point
    if possibleStations.shape[0] == 0:
        possibleStations = geoPorts[(geoPorts.Longitude > min(origin.maxx[0], location[0])) & 
                                    (geoPorts.Longitude < max(origin.maxx[0], location[0])) &
                                    (geoPorts.Latitude > min(origin.maxy[0], location[0])) &
                                    (geoPorts.Latitude < max(origin.maxy[0], location[0]))]
        if possibleStations.shape[0] == 0:
            possibleStations = geoPorts
            
    #Now get distance between each station and location
    possibleStations["distance"] = np.power(np.power(np.abs(possibleStations.Longitude - location[0]), 2) + 
                                           np.power(np.abs(possibleStations.Latitude - location[1]), 2), 1/2)
    
    ps = pd.DataFrame(possibleStations)
    
    #find entry with minimum distance and return
    station = ps[ps.distance == ps.distance.min()]
    
    script = "Please head towards " + str(station.Location[0]) + ", " + str(station.Country[0]) + ".\n In direction: Longitude = " + str(station.Longitude[0] - locV['x']) + ", Latitude = " + str(station.Latitude[0] - locV['y'])
    
    return station, script

# %%
nearestStation('Australia', 'Angola', (-50, 75))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py:831: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# (     Country   Location Longitude Latitude                    geometry  \
#  ID
#  2850  Brazil  Fortaleza   -3.7275 -38.5275  POINT (-38.52750 -3.72750)
#
#       distance
#  ID
#  2850  122.595  ,
#  'Please head towards Fortaleza, Brazil.\n In direction: Longitude = 46.2725, Latitude = 11.472499999999997')

# %%
#Add a colour scheme to which one can recognise the status of each station
color = []
for s in geoPorts.Location:
    status = (station_list[station_list.Location == s]).Status.values[0]
    uptime = float(((station_list[station_list.Location == s]).Uptime.values[0]).strip('%')) / 100
    
    c = None
    if status == 'Online':
        c = (0, 1, uptime)
    elif status == 'Offline > 10 minutes':
        c = (1, 115/256, uptime)
    elif status == 'Offline > 24 hours':
        c = (1, 0, uptime)
    elif status == "Dead":
        c = (0, 0, uptime)
        
    color.append(c)

geoPorts["Status"] = color

# %%
geoPorts[geoPorts.Status != (0, 1, 1)]
# Out:
#                        Country                    Location Longitude Latitude  \
# ID
# 2556                 Australia                    Franklin       -25      133
# 2637                 Australia                   Devonport  -41.1806  146.346
# 2936                 Australia                   Kettering  -43.1167  147.267
# 2465                 Australia                      Darwin  -12.4381  130.841
# 3292                 Australia          Oakleigh, Victoria   -37.913  145.102
# 3258                  Barbados                   St. James   13.2167 -59.6167
# 2713                   Belgium                      Leuven   50.8833      4.7
# 3359                   Belgium                     Schoten     51.25      4.5
# 2724                   Belgium                       Ghent   51.0536  3.72528
# 3283                   Belgium                   Diksmuide   51.0468   2.8436
# 2069                   Belgium                  Desteldonk   51.1214  3.78139
# 2127                   Belgium                      Izegem   50.9167      3.2
# 2850                    Brazil                   Fortaleza   -3.7275 -38.5275
# 2929                    Brazil                    Curitiba  -25.4167   -49.25
# 3019                  Bulgaria                       Varna   43.2167  27.9167
# 3238                    Canada   East Point Saturna Island     48.78  -123.15
# 2017                    Canada                Corner Brook   48.9396 -57.9397
# 2372                    Canada                   Vancouver     49.25   -123.1
# 2068                    Canada                     Galiano   48.9167 -123.417
# 2253                    Canada                    Montreal   45.5089 -73.5617
# 2218                    Canada     Newfoundland, St. Johns   47.5628 -52.7108
# 2955                    Canada                Bowen Island   49.3833 -123.383
# 2348                     Chile                Viña del Mar       -33 -71.5167
# 3294                     China                    Shanghai   31.2286  121.475
# 2151                     China                      Dalian    38.914  121.615
# 2356                     China               Zhangjiagang    31.8767  120.556
# 2443                  Colombia                Barranquilla   10.9639 -74.7964
# 2866                  Colombia             Puerto Colombia   12.2556 -71.9669
# 2368                   Denmark                  Copenhagen   55.6761  12.5683
# 2139                   Denmark              Islands Brygge   55.6667  12.5833
# ...                        ...                         ...       ...      ...
# 2986  United States of America             Canada, Alameda        37     -120
# 2081  United States of America                     Portage     43.55 -89.4667
# 3369  United States of America     Pickwick Dam, Tennessee   35.2236 -88.2369
# 2685  United States of America                     Alabama        40     -100
# 3261  United States of America                  Mamaroneck   40.9492 -73.7336
# 2407  United States of America                  Boca Raton   26.3686    -80.1
# 2619  United States of America                      Groves        40     -100
# 2436  United States of America   Treehouse, Virgin Islands   28.4038 -81.5794
# 2092  United States of America                    Bayfield   46.8117   -90.82
# 2537  United States of America           Savannah, Georgia   32.0167 -81.1167
# 2968  United States of America  Fort Walton Beach, Florida   30.4203 -86.6167
# 2570  United States of America               Mountain View        40     -100
# 3133  United States of America                   Edgewater   40.8238 -73.9742
# 3251  United States of America       Rolling Hills Estates   33.7736 -118.361
# 3069  United States of America                   Dabob Bay      47.5   -120.5
# 2523  United States of America             West Palm Beach    26.715 -80.0394
# 3045  United States of America                    New York   40.7127  -74.006
# 3001  United States of America                    Brooklyn   40.6603 -74.0044
# 2172  United States of America                  Navarre FL    30.401  -86.863
# 2891  United States of America                   Melbourne   38.8906 -77.0044
# 2349  United States of America                    Portland        40     -100
# 2657  United States of America                       Niles   41.1853 -80.7572
# 2727  United States of America                  Washingotn   38.9047 -77.0164
# 2646  United States of America               Arkwright, NY        55       -3
# 2466  United States of America                  Callao, VA     37.86   -76.38
# 2650  United States of America          Sabine Pass, Texas   29.7264 -93.8633
# 2071  United States of America         Fort Lauderdale, Fl   26.1333   -80.15
# 2048  United States of America                Adak, Alaska    51.872 -176.636
# 2656                   Unknown                    Cagliari   39.2278  9.11111
# 3146                   Unknown                      At Sea      65.5     37.5
#
#                          geometry                 Status
# ID
# 2556  POINT (133.00000 -25.00000)           (0, 1, 0.99)
# 2637  POINT (146.34639 -41.18056)           (0, 1, 0.91)
# 2936  POINT (147.26667 -43.11667)           (0, 1, 0.99)
# 2465  POINT (130.84111 -12.43806)           (0, 1, 0.98)
# 3292  POINT (145.10200 -37.91300)           (0, 1, 0.91)
# 3258   POINT (-59.61667 13.21667)           (0, 1, 0.47)
# 2713     POINT (4.70000 50.88333)  (1, 0.44921875, 0.51)
# 3359     POINT (4.50000 51.25000)           (0, 1, 0.89)
# 2724     POINT (3.72528 51.05361)           (0, 1, 0.95)
# 3283     POINT (2.84360 51.04680)           (1, 0, 0.02)
# 2069     POINT (3.78139 51.12139)            (0, 0, 0.0)
# 2127     POINT (3.20000 50.91667)           (0, 1, 0.99)
# 2850   POINT (-38.52750 -3.72750)           (0, 1, 0.99)
# 2929  POINT (-49.25000 -25.41667)  (1, 0.44921875, 0.15)
# 3019    POINT (27.91667 43.21667)           (0, 1, 0.93)
# 3238  POINT (-123.15000 48.78000)           (0, 1, 0.78)
# 2017   POINT (-57.93971 48.93960)           (0, 1, 0.98)
# 2372  POINT (-123.10000 49.25000)           (0, 1, 0.99)
# 2068  POINT (-123.41667 48.91667)           (0, 1, 0.99)
# 2253   POINT (-73.56167 45.50889)           (0, 1, 0.98)
# 2218   POINT (-52.71083 47.56278)           (0, 1, 0.97)
# 2955  POINT (-123.38333 49.38333)           (0, 1, 0.98)
# 2348  POINT (-71.51667 -33.00000)           (0, 1, 0.95)
# 3294   POINT (121.47472 31.22861)            (0, 0, 0.0)
# 2151   POINT (121.61480 38.91400)  (1, 0.44921875, 0.38)
# 2356   POINT (120.55600 31.87670)           (0, 1, 0.88)
# 2443   POINT (-74.79639 10.96389)  (1, 0.44921875, 0.82)
# 2866   POINT (-71.96694 12.25556)           (1, 0, 0.16)
# 2368    POINT (12.56833 55.67611)   (1, 0.44921875, 1.0)
# 2139    POINT (12.58333 55.66667)   (1, 0.44921875, 1.0)
# ...                           ...                    ...
# 2986  POINT (-120.00000 37.00000)            (0, 0, 0.0)
# 2081   POINT (-89.46667 43.55000)            (0, 0, 0.0)
# 3369   POINT (-88.23694 35.22361)           (0, 1, 0.36)
# 2685  POINT (-100.00000 40.00000)           (1, 0, 0.21)
# 3261   POINT (-73.73361 40.94917)           (1, 0, 0.36)
# 2407   POINT (-80.10000 26.36861)           (0, 1, 0.67)
# 2619  POINT (-100.00000 40.00000)           (0, 1, 0.95)
# 2436   POINT (-81.57940 28.40380)           (0, 1, 0.97)
# 2092   POINT (-90.82000 46.81167)           (0, 1, 0.99)
# 2537   POINT (-81.11667 32.01667)           (0, 1, 0.94)
# 2968   POINT (-86.61667 30.42028)            (0, 0, 0.0)
# 2570  POINT (-100.00000 40.00000)           (0, 1, 0.78)
# 3133   POINT (-73.97424 40.82380)           (0, 1, 0.87)
# 3251  POINT (-118.36083 33.77361)           (0, 1, 0.99)
# 3069  POINT (-120.50000 47.50000)           (0, 1, 0.95)
# 2523   POINT (-80.03944 26.71500)  (1, 0.44921875, 0.03)
# 3045   POINT (-74.00597 40.71274)           (0, 1, 0.96)
# 3001   POINT (-74.00444 40.66028)           (0, 1, 0.94)
# 2172   POINT (-86.86300 30.40100)   (1, 0.44921875, 0.6)
# 2891   POINT (-77.00444 38.89056)  (1, 0.44921875, 0.02)
# 2349  POINT (-100.00000 40.00000)            (0, 1, 0.9)
# 2657   POINT (-80.75722 41.18528)  (1, 0.44921875, 0.64)
# 2727   POINT (-77.01639 38.90472)           (1, 0, 0.18)
# 2646    POINT (-3.00000 55.00000)           (0, 1, 0.99)
# 2466   POINT (-76.38000 37.86000)           (0, 1, 0.97)
# 2650   POINT (-93.86333 29.72639)           (0, 1, 0.98)
# 2071   POINT (-80.15000 26.13333)           (0, 1, 0.93)
# 2048  POINT (-176.63600 51.87200)           (0, 1, 0.45)
# 2656     POINT (9.11111 39.22778)           (0, 1, 0.71)
# 3146    POINT (37.50000 65.50000)            (1, 0, 0.2)
#
# [242 rows x 6 columns]

# %%
color_code = """(r,g, b) = { (0, 1, u) if Online, 
                    (1, 0.4492, u) if 24hours >= Offline > 10mins, 
                    (1, 0, u) if Offline > 24hours, 
                    (0, 0, 0) if dead 
                }
                Where u = Uptime"""

fig, ax = plt.subplots(figsize = (20, 20))
world.plot(column='CDF', 
           legend=True,
           legend_kwds={'label': 'Likleyhood active ship belongs to country',
                        'orientation': 'horizontal'},
           ax=ax)
geoPorts[geoPorts.Status != (0, 1, 1)].plot(color=geoPorts[geoPorts.Status != (0, 1, 1)]["Status"], 
                                            legend=True,
                                            label=color_code,
                                            ax=ax)
plt.legend(loc='lower left')
plt.title('Map: AIS Stations Status')
plt.savefig('AISnetworkstatus.png')

# %%
def nearestStationInOperation(start, dest, location):
    """
    Function
    --------
    Function will take a coordinate pair, start 
    country and destination country, then return the nearest 
    station. Assume this is in the case of a lost and 
    stranded ship that is in need of finding its way back. We 
    will try to find this through checking the 2 norm. This
    time we will exclude stations that are offline, below 100%
    uptime or dead.
    
    Parameters
    ----------
    start: Country the ship left
    dest: Country the ship wants to get to
    location: Coordinates of ship
    
    Returns
    -------
    Station: Location the ship needs to go to to get back on 
    course.
    """
    
    global world, geoPorts
    origin = world[world.index == start].geometry.bounds
    end = world[world.index == dest].geometry.bounds
    
    #Assume longest route to get vector direction in unit form
    vector = {'x': end.maxx[0] - origin.minx[0], 'y': end.maxy[0] - origin.miny[0]}
    vector = {'x': vector['x'] / np.sqrt(pow(vector['x'], 2) + pow(vector['y'], 2)), 
          'y': vector['y'] / np.sqrt(pow(vector['x'], 2) + pow(vector['y'], 2))}
    
    locV = {'x': location[0], 'y': location[0]}
    
    station = geoPorts[geoPorts.Status == (0, 1.0, 1.0)].iloc[0, :]
    #First try and find if there are any stations between location and destination
    possibleStations = geoPorts[(geoPorts.Longitude > min(end.maxx[0], location[0])) & 
                                (geoPorts.Longitude < max(end.maxx[0], location[0])) &
                                (geoPorts.Latitude > min(end.maxy[0], location[0])) &
                                (geoPorts.Latitude < max(end.maxy[0], location[0])) &
                                (geoPorts.Status == (0, 1.0, 1.0))]
    #If empty check any towards start point
    if possibleStations.shape[0] == 0:
        possibleStations = geoPorts[(geoPorts.Longitude > min(origin.maxx[0], location[0])) & 
                                    (geoPorts.Longitude < max(origin.maxx[0], location[0])) &
                                    (geoPorts.Latitude > min(origin.maxy[0], location[0])) &
                                    (geoPorts.Latitude < max(origin.maxy[0], location[0])) &
                                    (geoPorts.Status == (0, 1.0, 1.0))]
        if possibleStations.shape[0] == 0:
            possibleStations = geoPorts[geoPorts.Status == (0, 1.0, 1.0)]
            
    #Now get distance between each station and location
    possibleStations["distance"] = np.power(np.power(np.abs(possibleStations.Longitude - location[0]), 2) + 
                                           np.power(np.abs(possibleStations.Latitude - location[1]), 2), 1/2)
    
    ps = pd.DataFrame(possibleStations)
    
    #find entry with minimum distance and return
    station = ps[ps.distance == ps.distance.min()]
    
    script = "Please head towards " + str(station.Location[0]) + ", " + str(station.Country[0]) + ".\n In direction: Longitude = " + str(station.Longitude[0] - locV['x']) + ", Latitude = " + str(station.Latitude[0] - locV['y'])
    
    return station, script

# %%
nearestStationInOperation('Australia', 'Angola', (-50, 75))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py:831: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# (     Country Location Longitude Latitude                     geometry  \
#  ID
#  2024  Brazil   Santos  -23.9369  -46.325  POINT (-46.32500 -23.93694)
#
#             Status distance
#  ID
#  2024  (0, 1, 1.0)  124.093  ,
#  'Please head towards Santos, Brazil.\n In direction: Longitude = 26.06305556, Latitude = 3.674999999999997')

# %%
world[world.continent == 'Europe'].Ship_circulation_est.sum()
# Out:
# 10784.0

# %%
#So less create a function that takes a series of rules
#based on known amount of ships in certain regions of 
#the world and predicts how many ships are in each 
#countries waters

#Expand geomtry and add as pairs of intervals to a new column called bounds
Bounds = world.geometry.bounds
world["bounds"] = [([Bounds.minx.iloc[c], Bounds.maxx.iloc[c]], [Bounds.miny.iloc[c], Bounds.maxy.iloc[c]]) for c in range(Bounds.shape[0])]
   
#Example rule function
def knowShipsNorthernHemisphere(N):
    global world
    north = world[world.bounds.minx >= 0]
    north.Ship_circulation_est = [0 for c in range(north.shape[0])]
    xsum = lambda x_: (N <= (north.CDF * x_).sum())
    return xsum

knowShipsNorthernHemisphere(50000)
# Out:
# <function __main__.knowShipsNorthernHemisphere.<locals>.<lambda>(x_)>

# %%
from scipy.optimize import linprog
def predictShipsPerCountry(Conditions_up, constraints_up, Conditions_eq=None, constraints_eq=None):
    """
    Function
    --------
    Calculates optimal prediction of ships per a country 
    using a set of conditions and constraints
    
    Parameters
    ----------
    Conditions: Set of conditions without contraints
                as matrix
                
    contraints: Vector of constraints
    
    Returns
    -------
    x_: array containing predicted ships for each country
    """
    global world
    c_ = np.array(-1 * world.CDF.values) #Assume maxization probems require the inverse of the minimise problem
    x_ = linprog(c_,
                 A_ub=Conditions_up,
                 b_ub=constraints_up,
                 A_eq=Conditions_eq,
                 b_eq=constraints_eq,
                 options={'maxiter': 100, 'disp': False, 'autoscale': False, 'presolve': False, 'rr': False, 'tol': 1.6e-11})
    return x_

# %%
#Now create a set of conditions and allocate a value for each one

#Assume that if each country has equal weight, 1, thae total ships in circulation is at most 100000
a0 = [1 for i in range(world.shape[0])]
b0 = 1e6

#Assume for every 1e9 $, a country can chose to have one ship
a1 = [1 * world.gdp_md_est.iloc[i] / 1e3 for i in range(world.shape[0])]
b1 = world.gdp_md_est.sum() / 1e3

#Assume for a every 1e6 people, a country must have one ship available
a2 = [-1 * world.pop_est.iloc[i] / 1e6 for i in range(world.shape[0])]
b2 = -7500

#Assume knowledge of number of ships around each continent
#Europe
a3 = [(1 if world.continent.iloc[i] == 'Europe' else 0) for i in range(world.shape[0])]
b3 = world.Ship_circulation_est[world.continent == 'Europe'].sum()

#North America
a4 = [(1 if world.continent.iloc[i] == 'North America' else 0) for i in range(world.shape[0])]
b4 = world.Ship_circulation_est[world.continent == 'North America'].sum()

#South America
a5 = [(1 if world.continent.iloc[i] == 'South America' else 0) for i in range(world.shape[0])]
b5 = world.Ship_circulation_est[world.continent == 'South America'].sum()

#Asia
a6 = [(1 if world.continent.iloc[i] == 'Asia' else 0) for i in range(world.shape[0])]
b6 = world.Ship_circulation_est[world.continent == 'Asia'].sum()

#Oceania
a7 = [(-1 if world.continent.iloc[i] == 'Oceania' else 0) for i in range(world.shape[0])]
b7 = world.Ship_circulation_est[world.continent == 'Oceania'].sum()

#Africa
a8 = [(1 if world.continent.iloc[i] == 'Africa' else 0) for i in range(world.shape[0])]
b8 = world.Ship_circulation_est[world.continent == 'Africa'].sum()

#Antarctica
a9 = [(1 if world.continent.iloc[i] == 'Antarctica' else 0) for i in range(world.shape[0])]
b9 = world.Ship_circulation_est[world.continent == 'Antarctica'].sum()

#Now put these rules into processible form for calculating the prediction
A_ub = np.array([a0, a1, a2]) 
A_eq = np.array([a3, a4, a5, a6, a7, a8, a9])
b_ub = np.array([b0, b1, b2])
b_eq = np.array([b3, b4, b5, b6, b7, b8, b9])

# %%
#Now calculate a prediction from the above rules
x_ = predictShipsPerCountry(A_ub, b_ub, A_eq, b_eq)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: OptimizeWarning: Unknown solver options: autoscale, rr

# %%
world["New_Ship_Est"] = x_.x
world[world.New_Ship_Est > 0].plot(column="New_Ship_Est", legend=True, 
                                   legend_kwds={'label': 'New Ship prediction', 'orientation': 'horizontal'})

plt.title('MAP: Linear Programming Prediction')

plt.savefig("LinProgPrediction.png")

#This definately did not produce the best prediction here. This is most likeyly the result of Greenland
#and Iceland having a disproportionate number of stataions for there population size.

# %%
#Create function to strip a substring from all elements in a series
def strip(series, sub):
    result = series
    for i in range(series.shape[0]):
        result.iloc[i] = series.values[i].strip(sub)
    return result

# %%
uptimeAsDecimal = strip(station_list.Uptime, '%').astype(float).values / 100
distinct = station_list.Distinct.values.astype(float)

m, b = np.polyfit(uptimeAsDecimal, distinct, 1)

#Plot Uptime by Distinct for each station 
plt.scatter(uptimeAsDecimal, distinct, label='Know values')
plt.plot(uptimeAsDecimal, m*uptimeAsDecimal+b, color='black', label='Regression line')
plt.xlabel('Uptime at station')
plt.ylabel('Distict ships detected')
plt.legend()
plt.title('Uptime vs Distinct')
plt.savefig('uptimeVSdistict.png')

#Evident outliers here

# %%
#Now look at the data per country, this might do well looking a plotting CDF against both pop_est and gdp_md_est
#Less take out countries where CDF = 0
from mpl_toolkits.mplot3d import Axes3D

hasShips = world[world.CDF > 0]

x = hasShips.pop_est.values.astype(float)
y = hasShips.gdp_md_est.values.astype(float)
z = hasShips.CDF.values.astype(float)

fig = plt.figure()
ax3d = fig.add_subplot(111, projection='3d')

ax3d.scatter(xs=x, ys=y, zs=z, c='red')
ax3d.set_xlabel('population estimate')
ax3d.set_ylabel('GDP (1e6 $)')
ax3d.set_zlabel('Likelyhood of ships')
# Out:
# Text(0.5, 0, 'Likelyhood of ships')

# %%
#There needs to be a method like numpy polyfit, but works this out for z = m * x + p * y + q
#This can be done with linear regression
from sklearn.linear_model import LinearRegression
X = np.array([[x[i], y[i]] for i in range(x.shape[0])])
reg = LinearRegression().fit(X, z)

step_x = (world.pop_est.max() - world.pop_est.min()) / 10
step_y = (world.gdp_md_est.max() - world.gdp_md_est.min()) / 10

xx , yy = np.meshgrid(np.arange(world.pop_est.min(), world.pop_est.max(), step_x),
                      np.arange(world.gdp_md_est.min(), world.gdp_md_est.max(), step_y))

zz = reg.coef_[0] * xx + reg.coef_[1] * yy + reg.intercept_

# %%
#Now lets plot with result from linear regression
fig = plt.figure(figsize = (20, 20))
ax3d = fig.add_subplot(111, projection='3d')

m0 = np.format_float_scientific(reg.coef_[0], precision=4)
m1 = np.format_float_scientific(reg.coef_[1], precision=4)
bstr = np.format_float_scientific(reg.intercept_, precision=4)

ax3d.scatter(xs=x, ys=y, zs=z, c='red', label='Known values from AISnetwork')

surf = ax3d.plot_surface(xx, yy, zz, alpha=0.4, color='black',
                         label='Predictive modelling regression plane: z = ' + str(m0) + 'x + ' + str(m1) + 'y + ' + str(bstr))
surf._facecolors2d = surf._facecolors3d
surf._edgecolors2d = surf._edgecolors3d

ax3d.set_xlabel('population estimate')
ax3d.set_ylabel('GDP (1e6 $)')
ax3d.set_zlabel('Likelyhood of ships')
ax3d.set_title('Population vs GDP vs CDF')
ax3d.legend()
plt.savefig('popVSgdpVScdf.png')

# %%
#Now for each country where cdf is zero as in unfound we shall estimate a new probability that they have ships
for i in range(world.shape[0]):
    if world.CDF.iloc[i] == 0:
        world.CDF.iloc[i] = reg.intercept_ + reg.coef_[0] * world.pop_est.iloc[i] + reg.coef_[1] * world.gdp_md_est.iloc[i]

world
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#                             pop_est                continent iso_a3  \
# Country
# Fiji                         920938                  Oceania    FJI
# Tanzania                   53950935                   Africa    TZA
# W. Sahara                    603253                   Africa    ESH
# Canada                     35623680            North America    CAN
# United States of America  326625791            North America    USA
# Kazakhstan                 18556698                     Asia    KAZ
# Uzbekistan                 29748859                     Asia    UZB
# Papua New Guinea            6909701                  Oceania    PNG
# Indonesia                 260580739                     Asia    IDN
# Argentina                  44293293            South America    ARG
# Chile                      17789267            South America    CHL
# Dem. Rep. Congo            83301151                   Africa    COD
# Somalia                     7531386                   Africa    SOM
# Kenya                      47615739                   Africa    KEN
# Sudan                      37345935                   Africa    SDN
# Chad                       12075985                   Africa    TCD
# Haiti                      10646714            North America    HTI
# Dominican Rep.             10734247            North America    DOM
# Russia                    142257519                   Europe    RUS
# Bahamas                      329988            North America    BHS
# Falkland Is.                   2931            South America    FLK
# Norway                      5320045                   Europe    -99
# Greenland                     57713            North America    GRL
# Fr. S. Antarctic Lands          140  Seven seas (open ocean)    ATF
# Timor-Leste                 1291358                     Asia    TLS
# South Africa               54841552                   Africa    ZAF
# Lesotho                     1958042                   Africa    LSO
# Mexico                    124574795            North America    MEX
# Uruguay                     3360148            South America    URY
# Brazil                    207353391            South America    BRA
# ...                             ...                      ...    ...
# Philippines               104256076                     Asia    PHL
# Malaysia                   31381992                     Asia    MYS
# Brunei                       443593                     Asia    BRN
# Slovenia                    1972126                   Europe    SVN
# Finland                     5491218                   Europe    FIN
# Slovakia                    5445829                   Europe    SVK
# Czechia                    10674723                   Europe    CZE
# Eritrea                     5918919                   Africa    ERI
# Japan                     126451398                     Asia    JPN
# Paraguay                    6943739            South America    PRY
# Yemen                      28036829                     Asia    YEM
# Saudi Arabia               28571770                     Asia    SAU
# Antarctica                     4050               Antarctica    ATA
# N. Cyprus                    265100                     Asia    -99
# Cyprus                      1221549                     Asia    CYP
# Morocco                    33986655                   Africa    MAR
# Egypt                      97041072                   Africa    EGY
# Libya                       6653210                   Africa    LBY
# Ethiopia                  105350020                   Africa    ETH
# Djibouti                     865267                   Africa    DJI
# Somaliland                  3500000                   Africa    -99
# Uganda                     39570125                   Africa    UGA
# Rwanda                     11901484                   Africa    RWA
# Bosnia and Herz.            3856181                   Europe    BIH
# Macedonia                   2103721                   Europe    MKD
# Serbia                      7111024                   Europe    SRB
# Montenegro                   642550                   Europe    MNE
# Kosovo                      1895250                   Europe    -99
# Trinidad and Tobago         1218208            North America    TTO
# S. Sudan                   13026129                   Africa    SSD
#
#                           gdp_md_est  \
# Country
# Fiji                          8374.0
# Tanzania                    150600.0
# W. Sahara                      906.5
# Canada                     1674000.0
# United States of America  18560000.0
# Kazakhstan                  460700.0
# Uzbekistan                  202300.0
# Papua New Guinea             28020.0
# Indonesia                  3028000.0
# Argentina                   879400.0
# Chile                       436100.0
# Dem. Rep. Congo              66010.0
# Somalia                       4719.0
# Kenya                       152700.0
# Sudan                       176300.0
# Chad                         30590.0
# Haiti                        19340.0
# Dominican Rep.              161900.0
# Russia                     3745000.0
# Bahamas                       9066.0
# Falkland Is.                   281.8
# Norway                      364700.0
# Greenland                     2173.0
# Fr. S. Antarctic Lands          16.0
# Timor-Leste                   4975.0
# South Africa                739100.0
# Lesotho                       6019.0
# Mexico                     2307000.0
# Uruguay                      73250.0
# Brazil                     3081000.0
# ...                              ...
# Philippines                 801900.0
# Malaysia                    863000.0
# Brunei                       33730.0
# Slovenia                     68350.0
# Finland                     224137.0
# Slovakia                    168800.0
# Czechia                     350900.0
# Eritrea                       9169.0
# Japan                      4932000.0
# Paraguay                     64670.0
# Yemen                        73450.0
# Saudi Arabia               1731000.0
# Antarctica                     810.0
# N. Cyprus                     3600.0
# Cyprus                       29260.0
# Morocco                     282800.0
# Egypt                      1105000.0
# Libya                        90890.0
# Ethiopia                    174700.0
# Djibouti                      3345.0
# Somaliland                   12250.0
# Uganda                       84930.0
# Rwanda                       21970.0
# Bosnia and Herz.             42530.0
# Macedonia                    29520.0
# Serbia                      101800.0
# Montenegro                   10610.0
# Kosovo                       18490.0
# Trinidad and Tobago          43570.0
# S. Sudan                     20880.0
#
#                                                                    geometry  \
# Country
# Fiji                      MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# Tanzania                  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# W. Sahara                 POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# Canada                    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# United States of America  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# Kazakhstan                POLYGON ((87.35997 49.21498, 86.59878 48.54918...
# Uzbekistan                POLYGON ((55.96819 41.30864, 55.92892 44.99586...
# Papua New Guinea          MULTIPOLYGON (((141.00021 -2.60015, 142.73525 ...
# Indonesia                 MULTIPOLYGON (((141.00021 -2.60015, 141.01706 ...
# Argentina                 MULTIPOLYGON (((-68.63401 -52.63637, -68.25000...
# Chile                     MULTIPOLYGON (((-68.63401 -52.63637, -68.63335...
# Dem. Rep. Congo           POLYGON ((29.34000 -4.49998, 29.51999 -5.41998...
# Somalia                   POLYGON ((41.58513 -1.68325, 40.99300 -0.85829...
# Kenya                     POLYGON ((39.20222 -4.67677, 37.76690 -3.67712...
# Sudan                     POLYGON ((24.56737 8.22919, 23.80581 8.66632, ...
# Chad                      POLYGON ((23.83766 19.58047, 23.88689 15.61084...
# Haiti                     POLYGON ((-71.71236 19.71446, -71.62487 19.169...
# Dominican Rep.            POLYGON ((-71.70830 18.04500, -71.68774 18.316...
# Russia                    MULTIPOLYGON (((178.72530 71.09880, 180.00000 ...
# Bahamas                   MULTIPOLYGON (((-78.98000 26.79000, -78.51000 ...
# Falkland Is.              POLYGON ((-61.20000 -51.85000, -60.00000 -51.2...
# Norway                    MULTIPOLYGON (((15.14282 79.67431, 15.52255 80...
# Greenland                 POLYGON ((-46.76379 82.62796, -43.40644 83.225...
# Fr. S. Antarctic Lands    POLYGON ((68.93500 -48.62500, 69.58000 -48.940...
# Timor-Leste               POLYGON ((124.96868 -8.89279, 125.08625 -8.656...
# South Africa              POLYGON ((16.34498 -28.57671, 16.82402 -28.082...
# Lesotho                   POLYGON ((28.97826 -28.95560, 29.32517 -29.257...
# Mexico                    POLYGON ((-117.12776 32.53534, -115.99135 32.6...
# Uruguay                   POLYGON ((-57.62513 -30.21629, -56.97603 -30.1...
# Brazil                    POLYGON ((-53.37366 -33.76838, -53.65054 -33.2...
# ...                                                                     ...
# Philippines               MULTIPOLYGON (((120.83390 12.70450, 120.32344 ...
# Malaysia                  MULTIPOLYGON (((100.08576 6.46449, 100.25960 6...
# Brunei                    POLYGON ((115.45071 5.44773, 115.40570 4.95523...
# Slovenia                  POLYGON ((13.80648 46.50931, 14.63247 46.43182...
# Finland                   POLYGON ((28.59193 69.06478, 28.44594 68.36461...
# Slovakia                  POLYGON ((22.55814 49.08574, 22.28084 48.82539...
# Czechia                   POLYGON ((15.01700 51.10667, 15.49097 50.78473...
# Eritrea                   POLYGON ((36.42951 14.42211, 36.32322 14.82249...
# Japan                     MULTIPOLYGON (((141.88460 39.18086, 140.95949 ...
# Paraguay                  POLYGON ((-58.16639 -20.17670, -57.87067 -20.7...
# Yemen                     POLYGON ((52.00001 19.00000, 52.78218 17.34974...
# Saudi Arabia              POLYGON ((34.95604 29.35655, 36.06894 29.19749...
# Antarctica                MULTIPOLYGON (((-48.66062 -78.04702, -48.15140...
# N. Cyprus                 POLYGON ((32.73178 35.14003, 32.80247 35.14550...
# Cyprus                    POLYGON ((32.73178 35.14003, 32.91957 35.08783...
# Morocco                   POLYGON ((-2.16991 35.16840, -1.79299 34.52792...
# Egypt                     POLYGON ((36.86623 22.00000, 32.90000 22.00000...
# Libya                     POLYGON ((25.00000 22.00000, 25.00000 20.00304...
# Ethiopia                  POLYGON ((47.78942 8.00300, 44.96360 5.00162, ...
# Djibouti                  POLYGON ((42.35156 12.54223, 42.77964 12.45542...
# Somaliland                POLYGON ((48.94820 11.41062, 48.94820 11.41062...
# Uganda                    POLYGON ((33.90371 -0.95000, 31.86617 -1.02736...
# Rwanda                    POLYGON ((30.41910 -1.13466, 30.81613 -1.69891...
# Bosnia and Herz.          POLYGON ((18.56000 42.65000, 17.67492 43.02856...
# Macedonia                 POLYGON ((22.38053 42.32026, 22.88137 41.99930...
# Serbia                    POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# Montenegro                POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# Kosovo                    POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# Trinidad and Tobago       POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# S. Sudan                  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
#
#                           Ship_circulation_est  Ships_per_1e6       CDF  \
# Country
# Fiji                                       NaN            NaN  0.382946
# Tanzania                                   NaN            NaN  0.371972
# W. Sahara                                  NaN            NaN  0.382680
# Canada                                   417.0      11.705697  0.536780
# United States of America                2306.0       7.060067  0.999670
# Kazakhstan                                 NaN            NaN  0.399633
# Uzbekistan                                 NaN            NaN  0.382836
# Papua New Guinea                           NaN            NaN  0.381887
# Indonesia                                485.0       1.861227  0.583793
# Argentina                                  NaN            NaN  0.411865
# Chile                                     11.0       0.618350  0.267677
# Dem. Rep. Congo                            NaN            NaN  0.357699
# Somalia                                    NaN            NaN  0.380504
# Kenya                                      NaN            NaN  0.374242
# Sudan                                      NaN            NaN  0.378935
# Chad                                       NaN            NaN  0.380251
# Haiti                                      NaN            NaN  0.380174
# Dominican Rep.                             NaN            NaN  0.387302
# Russia                                   434.0       3.050805  0.548608
# Bahamas                                    NaN            NaN  0.383183
# Falkland Is.                               NaN            NaN  0.382853
# Norway                                  2154.0     404.883793  0.999153
# Greenland                                 21.0     363.869492  0.273483
# Fr. S. Antarctic Lands                     NaN            NaN  0.382841
# Timor-Leste                                NaN            NaN  0.382649
# South Africa                              70.0       1.276404  0.302802
# Lesotho                                    NaN            NaN  0.382473
# Mexico                                    38.0       0.305038  0.283495
# Uruguay                                   30.0       8.928178  0.278762
# Brazil                                    86.0       0.414751  0.312671
# ...                                        ...            ...       ...
# Philippines                               21.0       0.201427  0.273483
# Malaysia                                  19.0       0.605443  0.272317
# Brunei                                     NaN            NaN  0.384382
# Slovenia                                 120.0      60.848039  0.334088
# Finland                                  222.0      40.428189  0.401398
# Slovakia                                  31.0       5.692430  0.279351
# Czechia                                    NaN            NaN  0.396813
# Eritrea                                    NaN            NaN  0.381279
# Japan                                    408.0       3.226536  0.530504
# Paraguay                                   NaN            NaN  0.383715
# Yemen                                      NaN            NaN  0.376951
# Saudi Arabia                               NaN            NaN  0.459995
# Antarctica                                 NaN            NaN  0.382879
# N. Cyprus                                  NaN            NaN  0.382930
# Cyprus                                    62.0      50.755230  0.297920
# Morocco                                    NaN            NaN  0.385430
# Egypt                                      NaN            NaN  0.405174
# Libya                                      NaN            NaN  0.385131
# Ethiopia                                   NaN            NaN  0.355625
# Djibouti                                   NaN            NaN  0.382712
# Somaliland                                 NaN            NaN  0.382260
# Uganda                                     NaN            NaN  0.373587
# Rwanda                                     NaN            NaN  0.379878
# Bosnia and Herz.                           NaN            NaN  0.383658
# Macedonia                                  NaN            NaN  0.383604
# Serbia                                     NaN            NaN  0.385522
# Montenegro                                 NaN            NaN  0.383153
# Kosovo                                     NaN            NaN  0.383121
# Trinidad and Tobago                        NaN            NaN  0.384612
# S. Sudan                                   NaN            NaN  0.379439
#
#                                                                      bounds  \
# Country
# Fiji                      ([-180.0, 180.0], [-18.28799, -16.020882256741...
# Tanzania                  ([29.339997592900346, 40.31659000000002], [-11...
# W. Sahara                 ([-17.06342322434257, -8.665124477564191], [20...
# Canada                    ([-140.99778, -52.64809872090421], [41.6751050...
# United States of America  ([-171.79111060289122, -66.96465999999998], [1...
# Kazakhstan                ([46.46644575377627, 87.35997033076265], [40.6...
# Uzbekistan                ([55.928917270741096, 73.05541710804917], [37....
# Papua New Guinea          ([141.00021040259185, 156.0199654482248], [-10...
# Indonesia                 ([95.29302615761729, 141.03385176001382], [-10...
# Argentina                 ([-73.4154357571201, -53.628348965048744], [-5...
# Chile                     ([-75.64439531116545, -66.95992000000001], [-5...
# Dem. Rep. Congo           ([12.182336866920252, 31.174149204235817], [-1...
# Somalia                   ([40.98105, 51.13387], [-1.6832500000000001, 1...
# Kenya                     ([33.893568969666944, 41.85508309264397], [-4....
# Sudan                     ([21.93680999999998, 38.410089959473225], [8.2...
# Chad                      ([13.540393507550789, 23.886890000000108], [7....
# Haiti                     ([-74.45803361682478, -71.62487321642283], [18...
# Dominican Rep.            ([-71.94511206733556, -68.31794328476897], [17...
# Russia                    ([-180.0, 180.00000000000006], [41.15141612402...
# Bahamas                   ([-78.98, -77.0], [23.710000000000004, 27.0400...
# Falkland Is.              ([-61.2, -57.75], [-52.300000000000004, -51.10...
# Norway                    ([4.992078077828978, 31.293418409965454], [58....
# Greenland                 ([-73.297, -12.20855], [60.03676000000001, 83....
# Fr. S. Antarctic Lands    ([68.72000000000001, 70.56], [-49.775000000000...
# Timor-Leste               ([124.96868248911623, 127.33592817597463], [-9...
# South Africa              ([16.344976840895242, 32.830120477028885], [-3...
# Lesotho                   ([26.999261915807637, 29.32516645683259], [-30...
# Mexico                    ([-117.12775999999985, -86.81198238803296], [1...
# Uruguay                   ([-58.42707414410439, -53.209588995971544], [-...
# Brazil                    ([-73.98723548042966, -34.729993455533034], [-...
# ...                                                                     ...
# Philippines               ([117.17427453010066, 126.53742394420061], [5....
# Malaysia                  ([100.0857568705271, 119.18190392463997], [0.7...
# Brunei                    ([114.20401655482837, 115.45071048386981], [4....
# Slovenia                  ([13.698109978905478, 16.564808383864857], [45...
# Finland                   ([20.645592889089528, 31.516092156711125], [59...
# Slovakia                  ([16.879982944413, 22.558137648211755], [47.75...
# Czechia                   ([12.240111118222558, 18.853144158613617], [48...
# Eritrea                   ([36.32321999999999, 43.08122602720016], [12.4...
# Japan                     ([129.40846316947255, 145.5431372418027], [31....
# Paraguay                  ([-62.685057135657885, -54.29295956075452], [-...
# Yemen                     ([42.60487267433362, 53.10857262554751], [12.5...
# Saudi Arabia              ([34.63233605320798, 55.666659376859826], [16....
# Antarctica                ([-179.99999999999994, 180.0], [-90.0, -63.270...
# N. Cyprus                 ([32.73178022637745, 34.576473829900465], [35....
# Cyprus                    ([32.25666710788596, 34.00488081232004], [34.5...
# Morocco                   ([-17.02042843267577, -1.1245511539663084], [2...
# Egypt                     ([24.70007, 36.86622999999997], [22.0, 31.58568])
# Libya                     ([9.319410841518163, 25.16482], [19.5804700000...
# Ethiopia                  ([32.954180000000065, 47.78942], [3.42206, 14....
# Djibouti                  ([41.66176000000013, 43.31785241066467], [10.9...
# Somaliland                ([42.55875999999995, 48.94820641459347], [7.99...
# Uganda                    ([29.579466180140884, 35.03599], [-1.443322442...
# Rwanda                    ([29.024926385216787, 30.816134881317712], [-2...
# Bosnia and Herz.          ([15.750026075918981, 19.59976000000006], [42....
# Macedonia                 ([20.463175083099202, 22.952377150166452], [40...
# Serbia                    ([18.829824792873946, 22.986018507588483], [42...
# Montenegro                ([18.45001688302086, 20.339800000000082], [41....
# Kosovo                    ([20.070700000000045, 21.77505000000002], [41....
# Trinidad and Tobago                      ([-61.95, -60.895], [10.0, 10.89])
# S. Sudan                  ([23.886979580860668, 35.29800711823298], [3.5...
#
#                           New_Ship_Est
# Country
# Fiji                          0.000000
# Tanzania                      0.000000
# W. Sahara                    50.551104
# Canada                        0.000000
# United States of America      0.000000
# Kazakhstan                    0.000000
# Uzbekistan                    0.000000
# Papua New Guinea              0.000000
# Indonesia                     0.000000
# Argentina                     0.000000
# Chile                         0.000000
# Dem. Rep. Congo               0.000000
# Somalia                       0.000000
# Kenya                         0.000000
# Sudan                         0.000000
# Chad                          0.000000
# Haiti                         0.000000
# Dominican Rep.                0.000000
# Russia                        0.000000
# Bahamas                       0.000000
# Falkland Is.                127.000000
# Norway                        0.000000
# Greenland                  2782.000000
# Fr. S. Antarctic Lands        0.000000
# Timor-Leste                   0.000000
# South Africa                  0.000000
# Lesotho                       0.000000
# Mexico                        0.000000
# Uruguay                       0.000000
# Brazil                        0.000000
# ...                                ...
# Philippines                   0.000000
# Malaysia                      0.000000
# Brunei                        0.000000
# Slovenia                      0.000000
# Finland                       0.000000
# Slovakia                      0.000000
# Czechia                       0.000000
# Eritrea                       0.000000
# Japan                         0.000000
# Paraguay                      0.000000
# Yemen                         0.000000
# Saudi Arabia                  0.000000
# Antarctica                    0.000000
# N. Cyprus                  3613.000000
# Cyprus                        0.000000
# Morocco                       0.000000
# Egypt                         0.000000
# Libya                         0.000000
# Ethiopia                      0.000000
# Djibouti                      0.000000
# Somaliland                    0.000000
# Uganda                        0.000000
# Rwanda                        0.000000
# Bosnia and Herz.              0.000000
# Macedonia                     0.000000
# Serbia                        0.000000
# Montenegro                 9301.977920
# Kosovo                        0.000000
# Trinidad and Tobago           0.000000
# S. Sudan                      0.000000
#
# [177 rows x 10 columns]

# %%
#Now plot
fig, ax = plt.subplots(figsize = (20, 20))
world.plot(column='CDF', 
           legend=True,
           legend_kwds={'label': 'Likleyhood active ship is in countrys waters',
                        'orientation': 'horizontal'},
           ax=ax)
plt.title('Map: CDF estimate 1')
plt.savefig('cdf1.png')

# %%
#Now less use this with a biased random coin generator to predict where tomorrows ships are

import random as rnd
def biased_binary_generator(n_sim):
    """
    Function
    --------
    Runs a biased coin flip that a ship is either in the waters of a country or 
    not. This simulation is run n_sim times and works out a total.
    
    Parameters
    ----------
    n_sim: number of times to run simulation
    
    Returns
    -------
    None
    """
    
    global world
    
    flip = lambda p: 1 if rnd.random() <= p else 0 #Assume equal weight for each country
    
    world["New_Ship_Est"] = [np.array([flip(world.CDF.iloc[i]) for n in range(n_sim)]).sum() for i in range(world.shape[0])]

# %%
#Consider each country has a single radar post and can see only one ship
#at a time. These tick every s, 1000 times, where s is an arbitrary
#length of time
biased_binary_generator(10000)
world.plot(column="New_Ship_Est")

# %%
#Now make a new column that combines a countries gdp with population
#call it gdp_per_capita. Antarctica will produce an infinite value
#as it has no population
worldExcAntarctica = world[(world.index != 'Antarctica') & ("Seven seas (open ocean)" != world.continent)]
worldExcAntarctica["gdp_per_capita"] = ((world.gdp_md_est * 1e6) / world.pop_est).round(2)

Antarctica = world[(world.index == 'Antarctica') | ("Seven seas (open ocean)" == world.continent)]
Antarctica["gdp_per_capita"] = [np.nan, np.nan]
world = worldExcAntarctica.append(Antarctica)

fig, ax = plt.subplots(figsize = (20, 20))
world.plot(column='gdp_per_capita', 
           legend=True,
           legend_kwds={'label': 'GDP per capita',
                        'orientation': 'horizontal'},
           ax=ax)
plt.title('Map: GDP per Capta')
plt.savefig('gdpPerCapita.png')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py:831: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
#Now less count number of known satations per a country
stations = geoPorts
stations.loc[stations.Country == "Taiwan (Province of China)", 'Country'] = 'Taiwan'
stations.loc[stations.Country == "Saint Martin (FR)", 'Country'] = 'France'
stations.loc[stations.Country == "Viet Nam", 'Country'] = 'Vietnam'
stations.loc[stations.Country == "Russian Federation", 'Country'] = 'Russia'

stations["weight"] = 1
stations = stations.set_index(['Country', 'Location'])
num_stations = stations.weight.sum(level='Country')

world["num_stations"] = 0
for country in world.index:
    try:
        world.loc[world.index == country, 'num_stations'] = num_stations[country]
    except:
        world.loc[world.index == country, 'num_stations'] = 0

# %%
#Now less plot these new columns against each other
AISnations = world[world.num_stations > 0]

m, b = np.polyfit(AISnations.gdp_per_capita, AISnations.num_stations, 1)

fig = plt.figure(figsize=(15, 15))
plt.scatter(AISnations.gdp_per_capita, AISnations.num_stations, color='red',
            label="Known data")
plt.plot(AISnations.gdp_per_capita, m*AISnations.gdp_per_capita + b, color='black',
         label="Regression line y = " + str(ffs(m, 4)) + 'x + ' + str(ffs(b, 4)))
plt.xlabel('GDP per Capita')
plt.ylabel('Number of stations')
plt.legend(loc='best')
plt.title('GDP per capta vs number of stations')
plt.savefig('gdpVSstations.png')

# %%
#Now is time to predict possible stations for each country not listed by AIS
world.loc[(world.num_stations == 0), 'num_stations'] = m*world.loc[(world.num_stations == 0), 'gdp_per_capita'] + b
world.num_stations = np.floor(world.num_stations)
world.loc[(world.num_stations < 0), 'num_stations'] = 0

# %%
fig, ax = plt.subplots(figsize = (20, 20))
world.plot(column='num_stations', 
           legend=True,
           legend_kwds={'label': 'Number of possible stations',
                        'orientation': 'horizontal'},
           ax=ax)
plt.title('Map: Est. Number of Stations')
plt.savefig('numstat.png')

# %%
#Now use the number of stations per a country as a weight for a new coin flip simulation
def weighted_biased_binary_generator(n_sim):
    """
    Function
    --------
    Runs a biased coin flip that a ship is either in the waters of a country or 
    not. This simulation is run n_sim times and works out a total. This time
    a weighting is considered.
    
    Parameters
    ----------
    n_sim: number of times to run simulation
    
    Returns
    -------
    None
    """
    
    global world
    
    flip = lambda p: 1 if rnd.random() <= p else 0 #Assume equal weight for each country
    
    for i in range(world.shape[0]):
        j = world.num_stations.iloc[i]
        
        total_est = 0
        while j > 0:
            total_est += np.array([flip(world.CDF.iloc[i]) for n in range(n_sim)]).sum()
            j -= 1
        
        world.New_Ship_Est.iloc[i] = total_est

# %%
#How many ships are there per 3600 s, where s is an arbitrary amount of time
weighted_biased_binary_generator(3600)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
fig, ax = plt.subplots(figsize = (20, 20))
world.plot(column='New_Ship_Est', 
           legend=True,
           legend_kwds={'label': 'Ships in countrys waters every 3600 s',
                        'orientation': 'horizontal'},
           ax=ax)
plt.title('Map: Ehip Est.')
plt.savefig('newshipest1.png')

# %%
#Plot CDF against gdp_per_capita
world2 = world[(world.index != 'Antarctica') & ("Seven seas (open ocean)" != world.continent)]

m, b = np.polyfit(world2.gdp_per_capita, world2.CDF, 1)

fig = plt.figure(figsize=(15, 15))
plt.scatter(world2.gdp_per_capita, world2.CDF, color='red',
            label='Known values')
plt.plot(world2.gdp_per_capita, m*world2.gdp_per_capita+b, color='black',
         label='Regression line: y = ' + str(ffs(m, 4)) + 'x + ' + str(ffs(b, 4)))
plt.xlabel('GDP per Capita')
plt.ylabel('Likelyhood of ships in countrys waters')
plt.legend()
plt.title('GDP per Capita vs CDF')
plt.savefig('gdpVScdf.png')

# %%
#Now try and consider a countrys area and indeed population density
world["area"] = world.geometry.area
world["pop_density"] = world.pop_est / (world.area * 1e3)

fig, ax = plt.subplots(figsize = (20, 20))
world.plot(column='pop_density', 
           legend=True,
           legend_kwds={'label': 'Population Density',
                        'orientation': 'horizontal'},
           ax=ax)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#Plot CDF against gdp_per_capita
world2 = world[(world.index != 'Antarctica') & ("Seven seas (open ocean)" != world.continent)]

m, b = np.polyfit(world2.pop_density, world2.CDF, 1)

fig = plt.figure(figsize=(15, 15))
plt.scatter(world2.pop_density, world2.CDF, color='red', label='Known AIS data')
plt.plot(world2.pop_density, m*world2.pop_density+b, color='black',
         label='Predicted line of regression: y = ' + str(np.format_float_scientific(m, 4)) + 'x + ' + str(np.format_float_scientific(b, 4)))
plt.xlabel('Population Density')
plt.ylabel('Likelyhood of ships in countrys waters')
plt.title('Pop. Density vs CDF')
plt.legend(loc='upper right')
plt.savefig('popdaseVScdf.png')

# %%
#Now consider wealth density or GDP density
world["gdp_density"] = (world.gdp_md_est) / world.area

fig, ax = plt.subplots(figsize = (20, 20))
world.plot(column='gdp_density', 
           legend=True,
           legend_kwds={'label': 'GDP Density',
                        'orientation': 'horizontal'},
           ax=ax)
plt.title('MAP: Wealth Density')
plt.savefig('wealthDense.png')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.

# %%
#Plot CDF against GPD density
world2 = world[(world.index != 'Antarctica') & ("Seven seas (open ocean)" != world.continent)]

m, b = np.polyfit(world2.gdp_density, world2.CDF, 1)

fig = plt.figure(figsize=(15, 15))
plt.scatter(world2.gdp_density, world2.CDF, color='red',
            label='Known AIS data')
plt.plot(world2.gdp_density, m*world2.gdp_density+b, color='black',
         label='Predicted regression line: y = ' + str(np.format_float_scientific(m, 4)) + 'x + ' + str(np.format_float_scientific(b, 4)))
plt.xlabel('GDP Density')
plt.ylabel('Likelyhood of ships in countrys waters')
plt.legend(loc='upper right')
plt.title('Wealth density vs CDF')
plt.savefig('gdpdenseVSCDF.png')

# %%
#Look at this logarithmicly
world["log_gdp_density"] = np.log((world.gdp_md_est) / world.area) / np.log(10)

fig, ax = plt.subplots(figsize = (20, 20))
world.plot(column='log_gdp_density', 
           legend=True,
           legend_kwds={'label': 'GDP Density (logarithmic base 10)',
                        'orientation': 'horizontal'},
           ax=ax)
plt.title('Map: Log_10 GDP Density')
plt.savefig('gdpdenselog10.png')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.

# %%
world2 = world[(world.index != 'Antarctica') & ("Seven seas (open ocean)" != world.continent)]

m, b = np.polyfit(world2.log_gdp_density, world2.CDF, 1)

fig = plt.figure(figsize=(15, 15))
plt.scatter(world2.log_gdp_density, world2.CDF, color='red',
            label="Known AIS data")
plt.plot(world2.log_gdp_density, m*world2.log_gdp_density+b, color='black',
         label='Predicted regression line: y = ' + str(ffs(m, 4)) + 'x + ' + str(ffs(b, 4)))
plt.xlabel('GDP Density (logarithmic base 10)')
plt.ylabel('Likelyhood of ships in countrys waters')
plt.legend(loc='upper left')
plt.title('Log_10 GDP density vs CDF')
plt.savefig('gdpdenselog10VScdf.png')

# %%
#Logarithmic Population density
world["log_pop_density"] = np.log((world.pop_est) / world.area) / np.log(10)

fig, ax = plt.subplots(figsize = (20, 20))
world.plot(column='log_pop_density', 
           legend=True,
           legend_kwds={'label': 'Population Density (logarithmic base 10)',
                        'orientation': 'horizontal'},
           ax=ax)
plt.title('Mop: log_10 Population Density')
plt.savefig('popdenselog10.png')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.

# %%
#Logarithmic gdp per capita
world["log_gdp_per_cap"] = np.log((world.gdp_md_est * 1e6) / world.pop_est) / np.log(10)

fig, ax = plt.subplots(figsize = (20, 20))
world.plot(column='log_gdp_per_cap', 
           legend=True,
           legend_kwds={'label': 'GDP Per Capita (logarithmic base 10)',
                        'orientation': 'horizontal'},
           ax=ax)
plt.title('Map: log_10 GDP per Capita')
plt.savefig('gdpperCaplog10.png')

# %%
#New predictions for CDF and station numbers could be predicted from these logarithmic columns
#First Antarctica and French Antarctic Islands must be removed again
world2 = world[(world.index != 'Antarctica') & ("Seven seas (open ocean)" != world.continent)]

#Gather the ones we know of
AIS = world2[world2.Ships_per_1e6 > 0]

#Gather the data
x0 = AIS.log_gdp_per_cap.values
x1 = AIS.log_gdp_density.values
x2 = AIS.log_pop_density.values

y_cdf = AIS.CDF
y_nst = AIS.num_stations

from sklearn.linear_model import LinearRegression
X = np.array([[x0[i], x1[i], x2[i]] for i in range(x.shape[0])])
reg_cdf = LinearRegression().fit(X, y_cdf)
reg_nst = LinearRegression().fit(X, y_nst)

m0, m1, m2 = reg_cdf.coef_
b_cdf = reg_cdf.intercept_

p0, p1, p2 = reg_nst.coef_
b_nst = reg_nst.intercept_

world2['new_CDF'] = 0
world2['new_nst'] = 0

world2.loc[(world2.Ships_per_1e6.isna()), 'new_CDF'] = m0*world2[(world2.Ships_per_1e6.isna())].log_gdp_per_cap + m1*world2[(world2.Ships_per_1e6.isna())].log_gdp_density + m2*world2[(world2.Ships_per_1e6.isna())].log_pop_density + b_cdf
world2.loc[(world2.Ships_per_1e6.isna()), 'new_nst'] = p0*world2[(world2.Ships_per_1e6.isna())].log_gdp_per_cap + p1*world2[(world2.Ships_per_1e6.isna())].log_gdp_density + p2*world2[(world2.Ships_per_1e6.isna())].log_pop_density + b_nst

world2.loc[(world2.Ships_per_1e6 > 0), 'new_CDF'] = AIS.CDF
world2.loc[(world2.Ships_per_1e6 > 0), 'new_nst'] = AIS.num_stations
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py:831: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
#Now remove the negatives
world2.loc[(world2.new_CDF < 0), 'new_CDF'] = 0
world2.loc[(world2.new_nst < 0), 'new_nst'] = 0

world2
# Out:
#                             pop_est      continent iso_a3  gdp_md_est  \
# Country
# Fiji                         920938        Oceania    FJI      8374.0
# Tanzania                   53950935         Africa    TZA    150600.0
# W. Sahara                    603253         Africa    ESH       906.5
# Canada                     35623680  North America    CAN   1674000.0
# United States of America  326625791  North America    USA  18560000.0
# Kazakhstan                 18556698           Asia    KAZ    460700.0
# Uzbekistan                 29748859           Asia    UZB    202300.0
# Papua New Guinea            6909701        Oceania    PNG     28020.0
# Indonesia                 260580739           Asia    IDN   3028000.0
# Argentina                  44293293  South America    ARG    879400.0
# Chile                      17789267  South America    CHL    436100.0
# Dem. Rep. Congo            83301151         Africa    COD     66010.0
# Somalia                     7531386         Africa    SOM      4719.0
# Kenya                      47615739         Africa    KEN    152700.0
# Sudan                      37345935         Africa    SDN    176300.0
# Chad                       12075985         Africa    TCD     30590.0
# Haiti                      10646714  North America    HTI     19340.0
# Dominican Rep.             10734247  North America    DOM    161900.0
# Russia                    142257519         Europe    RUS   3745000.0
# Bahamas                      329988  North America    BHS      9066.0
# Falkland Is.                   2931  South America    FLK       281.8
# Norway                      5320045         Europe    -99    364700.0
# Greenland                     57713  North America    GRL      2173.0
# Timor-Leste                 1291358           Asia    TLS      4975.0
# South Africa               54841552         Africa    ZAF    739100.0
# Lesotho                     1958042         Africa    LSO      6019.0
# Mexico                    124574795  North America    MEX   2307000.0
# Uruguay                     3360148  South America    URY     73250.0
# Brazil                    207353391  South America    BRA   3081000.0
# Bolivia                    11138234  South America    BOL     78350.0
# ...                             ...            ...    ...         ...
# Georgia                     4926330           Asia    GEO     37270.0
# Philippines               104256076           Asia    PHL    801900.0
# Malaysia                   31381992           Asia    MYS    863000.0
# Brunei                       443593           Asia    BRN     33730.0
# Slovenia                    1972126         Europe    SVN     68350.0
# Finland                     5491218         Europe    FIN    224137.0
# Slovakia                    5445829         Europe    SVK    168800.0
# Czechia                    10674723         Europe    CZE    350900.0
# Eritrea                     5918919         Africa    ERI      9169.0
# Japan                     126451398           Asia    JPN   4932000.0
# Paraguay                    6943739  South America    PRY     64670.0
# Yemen                      28036829           Asia    YEM     73450.0
# Saudi Arabia               28571770           Asia    SAU   1731000.0
# N. Cyprus                    265100           Asia    -99      3600.0
# Cyprus                      1221549           Asia    CYP     29260.0
# Morocco                    33986655         Africa    MAR    282800.0
# Egypt                      97041072         Africa    EGY   1105000.0
# Libya                       6653210         Africa    LBY     90890.0
# Ethiopia                  105350020         Africa    ETH    174700.0
# Djibouti                     865267         Africa    DJI      3345.0
# Somaliland                  3500000         Africa    -99     12250.0
# Uganda                     39570125         Africa    UGA     84930.0
# Rwanda                     11901484         Africa    RWA     21970.0
# Bosnia and Herz.            3856181         Europe    BIH     42530.0
# Macedonia                   2103721         Europe    MKD     29520.0
# Serbia                      7111024         Europe    SRB    101800.0
# Montenegro                   642550         Europe    MNE     10610.0
# Kosovo                      1895250         Europe    -99     18490.0
# Trinidad and Tobago         1218208  North America    TTO     43570.0
# S. Sudan                   13026129         Africa    SSD     20880.0
#
#                                                                    geometry  \
# Country
# Fiji                      MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# Tanzania                  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# W. Sahara                 POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# Canada                    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# United States of America  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# Kazakhstan                POLYGON ((87.35997 49.21498, 86.59878 48.54918...
# Uzbekistan                POLYGON ((55.96819 41.30864, 55.92892 44.99586...
# Papua New Guinea          MULTIPOLYGON (((141.00021 -2.60015, 142.73525 ...
# Indonesia                 MULTIPOLYGON (((141.00021 -2.60015, 141.01706 ...
# Argentina                 MULTIPOLYGON (((-68.63401 -52.63637, -68.25000...
# Chile                     MULTIPOLYGON (((-68.63401 -52.63637, -68.63335...
# Dem. Rep. Congo           POLYGON ((29.34000 -4.49998, 29.51999 -5.41998...
# Somalia                   POLYGON ((41.58513 -1.68325, 40.99300 -0.85829...
# Kenya                     POLYGON ((39.20222 -4.67677, 37.76690 -3.67712...
# Sudan                     POLYGON ((24.56737 8.22919, 23.80581 8.66632, ...
# Chad                      POLYGON ((23.83766 19.58047, 23.88689 15.61084...
# Haiti                     POLYGON ((-71.71236 19.71446, -71.62487 19.169...
# Dominican Rep.            POLYGON ((-71.70830 18.04500, -71.68774 18.316...
# Russia                    MULTIPOLYGON (((178.72530 71.09880, 180.00000 ...
# Bahamas                   MULTIPOLYGON (((-78.98000 26.79000, -78.51000 ...
# Falkland Is.              POLYGON ((-61.20000 -51.85000, -60.00000 -51.2...
# Norway                    MULTIPOLYGON (((15.14282 79.67431, 15.52255 80...
# Greenland                 POLYGON ((-46.76379 82.62796, -43.40644 83.225...
# Timor-Leste               POLYGON ((124.96868 -8.89279, 125.08625 -8.656...
# South Africa              POLYGON ((16.34498 -28.57671, 16.82402 -28.082...
# Lesotho                   POLYGON ((28.97826 -28.95560, 29.32517 -29.257...
# Mexico                    POLYGON ((-117.12776 32.53534, -115.99135 32.6...
# Uruguay                   POLYGON ((-57.62513 -30.21629, -56.97603 -30.1...
# Brazil                    POLYGON ((-53.37366 -33.76838, -53.65054 -33.2...
# Bolivia                   POLYGON ((-69.52968 -10.95173, -68.78616 -11.0...
# ...                                                                     ...
# Georgia                   POLYGON ((39.95501 43.43500, 40.07696 43.55310...
# Philippines               MULTIPOLYGON (((120.83390 12.70450, 120.32344 ...
# Malaysia                  MULTIPOLYGON (((100.08576 6.46449, 100.25960 6...
# Brunei                    POLYGON ((115.45071 5.44773, 115.40570 4.95523...
# Slovenia                  POLYGON ((13.80648 46.50931, 14.63247 46.43182...
# Finland                   POLYGON ((28.59193 69.06478, 28.44594 68.36461...
# Slovakia                  POLYGON ((22.55814 49.08574, 22.28084 48.82539...
# Czechia                   POLYGON ((15.01700 51.10667, 15.49097 50.78473...
# Eritrea                   POLYGON ((36.42951 14.42211, 36.32322 14.82249...
# Japan                     MULTIPOLYGON (((141.88460 39.18086, 140.95949 ...
# Paraguay                  POLYGON ((-58.16639 -20.17670, -57.87067 -20.7...
# Yemen                     POLYGON ((52.00001 19.00000, 52.78218 17.34974...
# Saudi Arabia              POLYGON ((34.95604 29.35655, 36.06894 29.19749...
# N. Cyprus                 POLYGON ((32.73178 35.14003, 32.80247 35.14550...
# Cyprus                    POLYGON ((32.73178 35.14003, 32.91957 35.08783...
# Morocco                   POLYGON ((-2.16991 35.16840, -1.79299 34.52792...
# Egypt                     POLYGON ((36.86623 22.00000, 32.90000 22.00000...
# Libya                     POLYGON ((25.00000 22.00000, 25.00000 20.00304...
# Ethiopia                  POLYGON ((47.78942 8.00300, 44.96360 5.00162, ...
# Djibouti                  POLYGON ((42.35156 12.54223, 42.77964 12.45542...
# Somaliland                POLYGON ((48.94820 11.41062, 48.94820 11.41062...
# Uganda                    POLYGON ((33.90371 -0.95000, 31.86617 -1.02736...
# Rwanda                    POLYGON ((30.41910 -1.13466, 30.81613 -1.69891...
# Bosnia and Herz.          POLYGON ((18.56000 42.65000, 17.67492 43.02856...
# Macedonia                 POLYGON ((22.38053 42.32026, 22.88137 41.99930...
# Serbia                    POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# Montenegro                POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# Kosovo                    POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# Trinidad and Tobago       POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# S. Sudan                  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
#
#                           Ship_circulation_est  Ships_per_1e6       CDF  \
# Country
# Fiji                                       NaN            NaN  0.382946
# Tanzania                                   NaN            NaN  0.371972
# W. Sahara                                  NaN            NaN  0.382680
# Canada                                   417.0      11.705697  0.536780
# United States of America                2306.0       7.060067  0.999670
# Kazakhstan                                 NaN            NaN  0.399633
# Uzbekistan                                 NaN            NaN  0.382836
# Papua New Guinea                           NaN            NaN  0.381887
# Indonesia                                485.0       1.861227  0.583793
# Argentina                                  NaN            NaN  0.411865
# Chile                                     11.0       0.618350  0.267677
# Dem. Rep. Congo                            NaN            NaN  0.357699
# Somalia                                    NaN            NaN  0.380504
# Kenya                                      NaN            NaN  0.374242
# Sudan                                      NaN            NaN  0.378935
# Chad                                       NaN            NaN  0.380251
# Haiti                                      NaN            NaN  0.380174
# Dominican Rep.                             NaN            NaN  0.387302
# Russia                                   434.0       3.050805  0.548608
# Bahamas                                    NaN            NaN  0.383183
# Falkland Is.                               NaN            NaN  0.382853
# Norway                                  2154.0     404.883793  0.999153
# Greenland                                 21.0     363.869492  0.273483
# Timor-Leste                                NaN            NaN  0.382649
# South Africa                              70.0       1.276404  0.302802
# Lesotho                                    NaN            NaN  0.382473
# Mexico                                    38.0       0.305038  0.283495
# Uruguay                                   30.0       8.928178  0.278762
# Brazil                                    86.0       0.414751  0.312671
# Bolivia                                    NaN            NaN  0.382969
# ...                                        ...            ...       ...
# Georgia                                    NaN            NaN  0.383029
# Philippines                               21.0       0.201427  0.273483
# Malaysia                                  19.0       0.605443  0.272317
# Brunei                                     NaN            NaN  0.384382
# Slovenia                                 120.0      60.848039  0.334088
# Finland                                  222.0      40.428189  0.401398
# Slovakia                                  31.0       5.692430  0.279351
# Czechia                                    NaN            NaN  0.396813
# Eritrea                                    NaN            NaN  0.381279
# Japan                                    408.0       3.226536  0.530504
# Paraguay                                   NaN            NaN  0.383715
# Yemen                                      NaN            NaN  0.376951
# Saudi Arabia                               NaN            NaN  0.459995
# N. Cyprus                                  NaN            NaN  0.382930
# Cyprus                                    62.0      50.755230  0.297920
# Morocco                                    NaN            NaN  0.385430
# Egypt                                      NaN            NaN  0.405174
# Libya                                      NaN            NaN  0.385131
# Ethiopia                                   NaN            NaN  0.355625
# Djibouti                                   NaN            NaN  0.382712
# Somaliland                                 NaN            NaN  0.382260
# Uganda                                     NaN            NaN  0.373587
# Rwanda                                     NaN            NaN  0.379878
# Bosnia and Herz.                           NaN            NaN  0.383658
# Macedonia                                  NaN            NaN  0.383604
# Serbia                                     NaN            NaN  0.385522
# Montenegro                                 NaN            NaN  0.383153
# Kosovo                                     NaN            NaN  0.383121
# Trinidad and Tobago                        NaN            NaN  0.384612
# S. Sudan                                   NaN            NaN  0.379439
#
#                                                                      bounds  \
# Country
# Fiji                      ([-180.0, 180.0], [-18.28799, -16.020882256741...
# Tanzania                  ([29.339997592900346, 40.31659000000002], [-11...
# W. Sahara                 ([-17.06342322434257, -8.665124477564191], [20...
# Canada                    ([-140.99778, -52.64809872090421], [41.6751050...
# United States of America  ([-171.79111060289122, -66.96465999999998], [1...
# Kazakhstan                ([46.46644575377627, 87.35997033076265], [40.6...
# Uzbekistan                ([55.928917270741096, 73.05541710804917], [37....
# Papua New Guinea          ([141.00021040259185, 156.0199654482248], [-10...
# Indonesia                 ([95.29302615761729, 141.03385176001382], [-10...
# Argentina                 ([-73.4154357571201, -53.628348965048744], [-5...
# Chile                     ([-75.64439531116545, -66.95992000000001], [-5...
# Dem. Rep. Congo           ([12.182336866920252, 31.174149204235817], [-1...
# Somalia                   ([40.98105, 51.13387], [-1.6832500000000001, 1...
# Kenya                     ([33.893568969666944, 41.85508309264397], [-4....
# Sudan                     ([21.93680999999998, 38.410089959473225], [8.2...
# Chad                      ([13.540393507550789, 23.886890000000108], [7....
# Haiti                     ([-74.45803361682478, -71.62487321642283], [18...
# Dominican Rep.            ([-71.94511206733556, -68.31794328476897], [17...
# Russia                    ([-180.0, 180.00000000000006], [41.15141612402...
# Bahamas                   ([-78.98, -77.0], [23.710000000000004, 27.0400...
# Falkland Is.              ([-61.2, -57.75], [-52.300000000000004, -51.10...
# Norway                    ([4.992078077828978, 31.293418409965454], [58....
# Greenland                 ([-73.297, -12.20855], [60.03676000000001, 83....
# Timor-Leste               ([124.96868248911623, 127.33592817597463], [-9...
# South Africa              ([16.344976840895242, 32.830120477028885], [-3...
# Lesotho                   ([26.999261915807637, 29.32516645683259], [-30...
# Mexico                    ([-117.12775999999985, -86.81198238803296], [1...
# Uruguay                   ([-58.42707414410439, -53.209588995971544], [-...
# Brazil                    ([-73.98723548042966, -34.729993455533034], [-...
# Bolivia                   ([-69.59042375352405, -57.49837114117099], [-2...
# ...                                                                     ...
# Georgia                   ([39.955008579270924, 46.63790815612058], [41....
# Philippines               ([117.17427453010066, 126.53742394420061], [5....
# Malaysia                  ([100.0857568705271, 119.18190392463997], [0.7...
# Brunei                    ([114.20401655482837, 115.45071048386981], [4....
# Slovenia                  ([13.698109978905478, 16.564808383864857], [45...
# Finland                   ([20.645592889089528, 31.516092156711125], [59...
# Slovakia                  ([16.879982944413, 22.558137648211755], [47.75...
# Czechia                   ([12.240111118222558, 18.853144158613617], [48...
# Eritrea                   ([36.32321999999999, 43.08122602720016], [12.4...
# Japan                     ([129.40846316947255, 145.5431372418027], [31....
# Paraguay                  ([-62.685057135657885, -54.29295956075452], [-...
# Yemen                     ([42.60487267433362, 53.10857262554751], [12.5...
# Saudi Arabia              ([34.63233605320798, 55.666659376859826], [16....
# N. Cyprus                 ([32.73178022637745, 34.576473829900465], [35....
# Cyprus                    ([32.25666710788596, 34.00488081232004], [34.5...
# Morocco                   ([-17.02042843267577, -1.1245511539663084], [2...
# Egypt                     ([24.70007, 36.86622999999997], [22.0, 31.58568])
# Libya                     ([9.319410841518163, 25.16482], [19.5804700000...
# Ethiopia                  ([32.954180000000065, 47.78942], [3.42206, 14....
# Djibouti                  ([41.66176000000013, 43.31785241066467], [10.9...
# Somaliland                ([42.55875999999995, 48.94820641459347], [7.99...
# Uganda                    ([29.579466180140884, 35.03599], [-1.443322442...
# Rwanda                    ([29.024926385216787, 30.816134881317712], [-2...
# Bosnia and Herz.          ([15.750026075918981, 19.59976000000006], [42....
# Macedonia                 ([20.463175083099202, 22.952377150166452], [40...
# Serbia                    ([18.829824792873946, 22.986018507588483], [42...
# Montenegro                ([18.45001688302086, 20.339800000000082], [41....
# Kosovo                    ([20.070700000000045, 21.77505000000002], [41....
# Trinidad and Tobago                      ([-61.95, -60.895], [10.0, 10.89])
# S. Sudan                  ([23.886979580860668, 35.29800711823298], [3.5...
#
#                           New_Ship_Est  gdp_per_capita  num_stations  \
# Country
# Fiji                              2669         9092.90           2.0
# Tanzania                             0         2791.43           0.0
# W. Sahara                            0         1502.69           0.0
# Canada                           34792        46991.21          18.0
# United States of America        302311        56823.44          84.0
# Kazakhstan                       10069        24826.62           7.0
# Uzbekistan                        1443         6800.26           1.0
# Papua New Guinea                     0         4055.17           0.0
# Indonesia                         6354        11620.20           3.0
# Argentina                         7385        19854.02           5.0
# Chile                              947        24514.78           1.0
# Dem. Rep. Congo                      0          792.43           0.0
# Somalia                              0          626.58           0.0
# Kenya                                0         3206.92           0.0
# Sudan                                0         4720.73           0.0
# Chad                                 0         2533.13           0.0
# Haiti                                0         1816.52           0.0
# Dominican Rep.                    5643        15082.57           4.0
# Russia                           15836        26325.50           8.0
# Bahamas                          10862        27473.73           8.0
# Falkland Is.                     42694        96144.66          31.0
# Norway                          111517        68552.05          31.0
# Greenland                          988        37651.83           1.0
# Timor-Leste                          0         3852.53           0.0
# South Africa                      2221        13477.01           2.0
# Lesotho                              0         3073.99           0.0
# Mexico                            2971        18518.99           3.0
# Uruguay                            975        21799.64           1.0
# Brazil                            4590        14858.69           4.0
# Bolivia                           1388         7034.33           1.0
# ...                                ...             ...           ...
# Georgia                           1361         7565.47           1.0
# Philippines                       1025         7691.64           1.0
# Malaysia                           956        27499.85           1.0
# Brunei                           33129        76038.17          24.0
# Slovenia                          1205        34658.03           1.0
# Finland                          13076        40817.36           9.0
# Slovakia                          1000        30996.20           1.0
# Czechia                          14460        32872.05          10.0
# Eritrea                              0         1549.10           0.0
# Japan                            11346        39003.13           6.0
# Paraguay                          2693         9313.43           2.0
# Yemen                                0         2619.77           0.0
# Saudi Arabia                     31377        60584.28          19.0
# N. Cyprus                         4178        13579.78           3.0
# Cyprus                            1095        23953.19           1.0
# Morocco                           1360         8320.91           1.0
# Egypt                             2913        11386.93           2.0
# Libya                             4136        13661.07           3.0
# Ethiopia                             0         1658.28           0.0
# Djibouti                             0         3865.86           0.0
# Somaliland                           0         3500.00           0.0
# Uganda                               0         2146.32           0.0
# Rwanda                               0         1845.99           0.0
# Bosnia and Herz.                  2851        11029.05           2.0
# Macedonia                         4097        14032.28           3.0
# Serbia                            4168        14315.80           3.0
# Montenegro                        5482        16512.33           4.0
# Kosovo                            2800         9755.97           2.0
# Trinidad and Tobago              15356        35765.65          11.0
# S. Sudan                             0         1602.93           0.0
#
#                                  area  pop_density    gdp_density  \
# Country
# Fiji                         1.639511   561.715049    5107.620517
# Tanzania                    76.301964   707.071384    1973.736886
# W. Sahara                    8.603984    70.113216     105.358166
# Canada                    1712.995228    20.796135     977.235647
# United States of America  1122.281921   291.037203   16537.734108
# Kazakhstan                 330.586822    56.132600    1393.582469
# Uzbekistan                  49.958821   595.467599    4049.334979
# Papua New Guinea            37.991091   181.876878     737.541340
# Indonesia                  148.135821  1759.066353   20440.700782
# Argentina                  278.923392   158.800926    3152.837032
# Chile                       86.508469   205.636132    5041.124921
# Dem. Rep. Congo            189.515232   439.548578     348.309733
# Somalia                     39.528186   190.532040     119.383165
# Kenya                       48.033195   991.309014    3179.051499
# Sudan                      156.444543   238.716763    1126.916902
# Chad                       107.167364   112.683419     285.441378
# Haiti                        2.447114  4350.723103    7903.188233
# Dominican Rep.               4.129206  2599.590745   39208.501694
# Russia                    2935.205205    48.465954    1275.890351
# Bahamas                      1.399757   235.746698    6476.840271
# Falkland Is.                 2.128750     1.376864     132.378156
# Norway                      90.496255    58.787460    4030.001012
# Greenland                  677.509565     0.085184       3.207335
# Timor-Leste                  1.208939  1068.174485    4115.178026
# South Africa               112.718524   486.535400    6557.041170
# Lesotho                      2.561880   764.298899    2349.446577
# Mexico                     175.207341   711.013558   13167.256489
# Uruguay                     17.027171   197.340356    4301.947744
# Brazil                     710.185243   291.970853    4338.304731
# Bolivia                     92.077173   120.966289     850.916652
# ...                               ...          ...            ...
# Georgia                      7.520855   655.022617    4955.553719
# Philippines                 24.289232  4292.275581   33014.630135
# Malaysia                    27.543366  1139.366618   31332.408461
# Brunei                       0.872053   508.676593   38678.837294
# Slovenia                     2.225310   886.225440   30714.826953
# Finland                     63.782393    86.093007    3514.088928
# Slovakia                     5.753425   946.536970   29339.048377
# Czechia                     10.136967  1053.049005   34615.876772
# Eritrea                     10.045388   589.217534     912.757138
# Japan                       41.405110  3054.004615  119115.731419
# Paraguay                    35.429306   195.988570    1825.325060
# Yemen                       38.475618   728.690809    1909.001191
# Saudi Arabia               170.868605   167.214861   10130.591302
# N. Cyprus                    0.374644   707.604967    9609.120639
# Cyprus                       0.613351  1991.600199   47705.185655
# Morocco                     55.388992   613.599453    5105.707679
# Egypt                       90.395960  1073.511156   12223.997566
# Libya                      148.853147    44.696468     610.601803
# Ethiopia                    93.130693  1131.206235    1875.858488
# Djibouti                     1.814802   476.783178    1843.176419
# Somaliland                  13.800262   253.618380     887.664330
# Uganda                      19.976533  1980.830453    4251.488475
# Rwanda                       1.899400  6265.918076   11566.811344
# Bosnia and Herz.             5.696666   676.918937    7465.770511
# Macedonia                    2.706996   777.142358   10905.078383
# Serbia                       8.604719   826.409817   11830.717960
# Montenegro                   1.479321   434.354806    7172.211494
# Kosovo                       1.231641  1538.800137   15012.486235
# Trinidad and Tobago          0.639000  1906.428795   68184.663537
# S. Sudan                    51.196106   254.435934     407.843519
#
#                           log_gdp_density  log_pop_density  log_gdp_per_cap  \
# Country
# Fiji                             3.708219         5.749516         3.958703
# Tanzania                         3.295289         5.849463         3.445826
# W. Sahara                        2.022668         4.845800         3.176868
# Canada                           2.989999         4.317983         4.672017
# United States of America         4.218476         5.463949         4.754527
# Kazakhstan                       3.144133         4.749215         4.394918
# Uzbekistan                       3.607384         5.774858         3.832526
# Papua New Guinea                 2.867786         5.259777         3.608009
# Indonesia                        4.310496         6.245282         4.065214
# Argentina                        3.498702         5.200853         4.297848
# Chile                            3.702527         5.313099         4.389428
# Dem. Rep. Congo                  2.541966         5.643007         2.898959
# Somalia                          2.076943         5.279968         2.796975
# Kenya                            3.502298         5.996209         3.506089
# Sudan                            3.051892         5.377883         3.674009
# Chad                             2.455517         5.051860         3.403657
# Haiti                            3.897802         6.638561         3.259241
# Dominican Rep.                   4.593380         6.414905         4.178475
# Russia                           3.105813         4.685437         4.420377
# Bahamas                          3.811363         5.372446         4.438918
# Falkland Is.                     2.121816         3.138891         4.982925
# Norway                           3.605305         4.769285         4.836020
# Greenland                        0.506144         1.930358         4.575786
# Timor-Leste                      3.614389         6.028642         3.585746
# South Africa                     3.816708         5.687114         4.129593
# Lesotho                          3.370966         5.883263         3.487702
# Mexico                           4.119495         5.851878         4.267617
# Uruguay                          3.633665         5.295216         4.338449
# Brazil                           3.637320         5.465339         4.171981
# Bolivia                          2.929887         5.082664         3.847223
# ...                                   ...              ...              ...
# Georgia                          3.695092         5.816256         3.878836
# Philippines                      4.518706         6.632688         3.886019
# Malaysia                         4.495994         6.056663         4.439330
# Brunei                           4.587473         5.706442         4.881032
# Slovenia                         4.487348         5.947544         4.539804
# Finland                          3.545813         4.934968         4.610845
# Slovakia                         4.467446         5.976138         4.491308
# Czechia                          4.539275         6.022449         4.516827
# Eritrea                          2.960355         5.770276         3.190080
# Japan                            5.075969         6.484870         4.591099
# Paraguay                         3.261340         5.292231         3.969109
# Yemen                            3.280806         5.862543         3.418263
# Saudi Arabia                     4.005635         5.223275         4.782360
# N. Cyprus                        3.982684         5.849791         4.132893
# Cyprus                           4.678566         6.299202         4.379363
# Morocco                          3.708056         5.787885         3.920171
# Egypt                            4.087213         6.030807         4.056407
# Libya                            2.785758         4.650273         4.135485
# Ethiopia                         3.273200         6.053542         3.219658
# Djibouti                         3.265567         5.678321         3.587246
# Somaliland                       2.948249         5.404181         3.544068
# Uganda                           3.628541         6.296847         3.331694
# Rwanda                           4.063214         6.796985         3.266229
# Bosnia and Herz.                 3.873075         5.830537         4.042538
# Macedonia                        4.037629         5.890501         4.147128
# Serbia                           4.073011         5.917195         4.155816
# Montenegro                       3.855653         5.637845         4.217808
# Kosovo                           4.176453         6.187182         3.989270
# Trinidad and Tobago              4.833687         6.280221         4.553466
# S. Sudan                         2.610494         5.405578         3.204915
#
#                            new_CDF  new_nst
# Country
# Fiji                      0.296875      0.0
# Tanzania                  0.109375      0.0
# W. Sahara                 0.000000      0.0
# Canada                    0.536780     18.0
# United States of America  0.999670     84.0
# Kazakhstan                0.375000      5.0
# Uzbekistan                0.234375      0.0
# Papua New Guinea          0.125000      0.0
# Indonesia                 0.583793      3.0
# Argentina                 0.359375      4.0
# Chile                     0.267677      1.0
# Dem. Rep. Congo           0.000000      0.0
# Somalia                   0.000000      0.0
# Kenya                     0.140625      0.0
# Sudan                     0.156250      0.0
# Chad                      0.046875      0.0
# Haiti                     0.093750      0.0
# Dominican Rep.            0.421875      4.5
# Russia                    0.548608      8.0
# Bahamas                   0.421875      9.5
# Falkland Is.              0.484375     18.0
# Norway                    0.999153     31.0
# Greenland                 0.273483      1.0
# Timor-Leste               0.171875      0.0
# South Africa              0.302802      2.0
# Lesotho                   0.140625      0.0
# Mexico                    0.283495      3.0
# Uruguay                   0.278762      1.0
# Brazil                    0.312671      4.0
# Bolivia                   0.234375      0.0
# ...                            ...      ...
# Georgia                   0.265625      0.0
# Philippines               0.273483      1.0
# Malaysia                  0.272317      1.0
# Brunei                    0.578125     25.0
# Slovenia                  0.334088      1.0
# Finland                   0.401398      9.0
# Slovakia                  0.279351      1.0
# Czechia                   0.500000     14.0
# Eritrea                   0.015625      0.0
# Japan                     0.530504      6.0
# Paraguay                  0.265625      0.0
# Yemen                     0.109375      0.0
# Saudi Arabia              0.562500     20.0
# N. Cyprus                 0.359375      1.0
# Cyprus                    0.297920      1.0
# Morocco                   0.281250      0.0
# Egypt                     0.328125      0.0
# Libya                     0.265625      0.0
# Ethiopia                  0.031250      0.0
# Djibouti                  0.156250      0.0
# Somaliland                0.140625      0.0
# Uganda                    0.078125      0.0
# Rwanda                    0.093750      0.0
# Bosnia and Herz.          0.296875      0.0
# Macedonia                 0.375000      1.0
# Serbia                    0.375000      2.0
# Montenegro                0.390625      3.0
# Kosovo                    0.312500      0.0
# Trinidad and Tobago       0.515625     16.5
# S. Sudan                  0.000000      0.0
#
# [175 rows x 20 columns]

# %%
#Plot new CDF
fig, ax = plt.subplots(figsize = (20, 20))
world2.plot(column='new_CDF', 
           legend=True,
           legend_kwds={'label': 'Likelyhood of ships in countrys waters',
                        'orientation': 'horizontal'},
           ax=ax)
plt.title('Map: New CDF estimate')
plt.savefig('CDF2.png')

# %%
#Plot new estimation of number of stations
fig, ax = plt.subplots(figsize = (20, 20))
world2.plot(column='new_nst', 
           legend=True,
           legend_kwds={'label': 'Possible number of stations',
                        'orientation': 'horizontal'},
           ax=ax)
plt.title('Map: New Station estimate')
plt.savefig('newnumstatest.png')

# %%
strCDF = 'CDF = ' + ffs(m0, 4) + ' * GDP per Capita + ' + ffs(m1, 4) + ' * GDP Density + ' + ffs(m2, 4) + ' * Population Density + ' + ffs(b_cdf, 4)
print(strCDF)

strSQLOSS = 'Square loss, R^2 = ' + ffs(reg_cdf.score(X, y_cdf), 4) 
print(strSQLOSS)

#The coefficients are very large, now look at logistic regression for number of distinct ships
# Out:
# CDF = -1.6248e+13 * GDP per Capita + 1.6248e+13 * GDP Density + -1.6248e+13 * Population Density + 9.7488e+13
# Square loss, R^2 = 1.5234e-01

# %%
#Set the known number of stations as the weight
#weights = AIS.num_stations.values

from sklearn.linear_model import LogisticRegression
y_train = AIS.Ship_circulation_est.values

X_train = X
lreg = LogisticRegression(multi_class='multinomial', solver='lbfgs').fit(X_train, y_train)

notAIS = world2[world2.Ship_circulation_est.isna()]
X_test = notAIS.iloc[:, [17, 15, 16]].values

world2.loc[world2.Ship_circulation_est.isna(), "New_Ship_Est"] = lreg.predict(X_test)
world2.loc[world2.Ship_circulation_est > 0, "New_Ship_Est"] = y_train
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py:831: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
#Now give a weight to each station

#Define f(x) as a lambda function of the following
f = lambda x: 1 if x == 'Online' else (0 if x == 'Dead' else (np.exp(-1/6) if x == 'Offline > 10 minutes' else np.exp(-24)))

for s in geoPorts.Location:
    status = (station_list[station_list.Location == s]).Status.values[0]
    uptime = int(((station_list[station_list.Location == s]).Uptime.values[0]).strip('%'))
    
    geoPorts.loc[geoPorts.Location == s, "weight"] = (uptime * f(status)) / 100

# %%
from matplotlib import cm

fig, ax = plt.subplots(figsize = (20, 20))
world.plot(ax=ax, color='gray')
geoPorts.plot(column='weight',
              cmap = 'jet',
              legend=True,
              legend_kwds={'label': 'Efficiency of station',
                        'orientation': 'horizontal'},
              ax=ax)
plt.legend(loc='lower left')
plt.title('Map: AIS Stations Status')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1, 'Map: AIS Stations Status')

# %%
world2['mean_weight'] = 1.0 #set defualt as 1
stations = geoPorts.set_index(['Country', 'Location'])
world2.loc[world2.Ship_circulation_est > 0, "mean_weight"] = stations.weight.mean(level='Country')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py:831: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
#Find weights for each class based on mean number of stations and mean efficiency score
AIS = world2[world2.Ship_circulation_est > 0]
ns_norm_inf = AIS.num_stations.max()
res = []
labels = []
for y in lreg.classes_:
    subDF = AIS[AIS.Ship_circulation_est == y]
    ns = subDF.num_stations.mean()
    mu_wprime = subDF.mean_weight.mean()
    res.append(pow(np.abs(0.5 - (ns / ns_norm_inf)), mu_wprime))
    labels.append(y)

weights = {labels[j]: res[j] for j in range(lreg.classes_.shape[0])}
weights
# Out:
# {2.0: 0.5132267103693976,
#  10.0: 0.5015752010401037,
#  11.0: 0.5059170805611302,
#  19.0: 0.4880952380952381,
#  21.0: 0.4880952380952381,
#  22.0: 0.4880952380952381,
#  30.0: 0.681318129299105,
#  31.0: 0.4880952380952381,
#  32.0: 0.483022985386962,
#  33.0: 0.4880952380952381,
#  38.0: 0.47146517028451174,
#  45.0: 0.47619047619047616,
#  47.0: 0.4880952380952381,
#  57.0: 0.4880952380952381,
#  62.0: 0.4880952380952381,
#  66.0: 0.47619047619047616,
#  70.0: 0.47619047619047616,
#  80.0: 0.4523809523809524,
#  86.0: 0.5389570077581618,
#  106.0: 0.47619047619047616,
#  117.0: 0.5896612464782871,
#  120.0: 0.4880952380952381,
#  127.0: 0.4484934908683231,
#  162.0: 0.4426484047113902,
#  183.0: 0.4656576143969084,
#  222.0: 0.4027680969890416,
#  271.0: 0.44849560215278556,
#  299.0: 0.43192513135119875,
#  311.0: 0.4390183776190594,
#  329.0: 0.32682397345851505,
#  335.0: 0.27847486038129005,
#  353.0: 0.46511640715896463,
#  408.0: 0.5048535252865609,
#  417.0: 0.2923523145307139,
#  434.0: 0.40476190476190477,
#  485.0: 0.6057588154505524,
#  486.0: 0.39960445377963344,
#  783.0: 0.3027679172626185,
#  917.0: 0.14079146983046548,
#  947.0: 0.36941987858160896,
#  972.0: 0.03397030317314323,
#  1684.0: 0.3467302507669389,
#  2050.0: 0.45315237878110026,
#  2154.0: 0.1827312903718477,
#  2306.0: 0.5752885262739528}

# %%
#Now recompute the logistic regression
from sklearn.linear_model import LogisticRegression
y_train = AIS.Ship_circulation_est.values

X_train = X
lregw = LogisticRegression(multi_class='multinomial', solver='lbfgs', class_weight=weights).fit(X_train, y_train)

notAIS = world2[world2.Ship_circulation_est.isna()]
X_test = notAIS.iloc[:, [17, 15, 16]].values

world2.loc[world2.Ship_circulation_est.isna(), "New_Ship_Est"] = lregw.predict(X_test)
world2.loc[world2.Ship_circulation_est > 0, "New_Ship_Est"] = y_train
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py:831: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
#Get new cdf prediction using new ship estimate
mu = AIS.New_Ship_Est.mean()
sig = AIS.New_Ship_Est.std()

gaussCDF = lambda x: 0.5 * (1 + erf((x - mu)/(sig * np.sqrt(2))))
world2.loc[world2.Ship_circulation_est.isna(), "new_CDF"] = [gaussCDF(y) for y in world2[world2.Ship_circulation_est.isna()].New_Ship_Est]
world2.loc[world2.Ship_circulation_est > 0, "new_CDF"] = world2[world2.Ship_circulation_est > 0].CDF

# %%
fig, ax = plt.subplots(figsize = (20, 20))
world2.plot(column='new_CDF', 
           legend=True,
           legend_kwds={'label': 'Likelyhood of ships in countrys waters',
                        'orientation': 'horizontal'},
           ax=ax)
geoPorts.plot(column='weight',
              cmap = 'jet',
              legend=True,
              legend_kwds={'label': 'Efficiency of station',
                        'orientation': 'horizontal'},
              ax=ax)
plt.title('Map: New CDF estimate plus AIS stations')
# Out:
# Text(0.5, 1, 'Map: New CDF estimate plus AIS stations')

# %%
from pattern import web
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

url = ["http://www.aishub.net/stations?page=" + str(i) for i in range(1, 16)]

def getTable(html):
    """
    Function
    --------
    Scans html for data table and returns as a dataframe.
    
    Parameters
    ----------
    html : URL address of data table
    
    Returns
    -------
    Full dataframe
    """
    
    #Nested functions
    def extractfromi(element):
        if '<i' in str(element):
            return web.Element(element)('i')[0].attrs['title']
        else:
            return element
        
    def extractfromspan(element):
        if '<span' in str(element):
            span = web.Element(element)('span')[0]
            if span.content == '': #Get tile
                return span.attrs['title']
            else:
                return span.content
        else:
            element
        
    def extractfroma(element):
        if '<a ' in str(element):
            a = web.Element(element)('a')[0]
            if a.content == '': #Get tile
                try:
                    return a.attrs['title']
                except:
                    return None
            else:
                return a.content
        else:
            return element
        
    
    #Extract all data from webpage
    u = web.URL(html)
    code = u.download(cached=True)
    dom = web.Element(code)
    
    #get list of headers of data columns
    table_header = dom('tr')[0]
    headers = [table_header('th a')[i].content for i in range(len(table_header('th a')))]
    headers.append('Source')
    
    #Define the result as a dataframe containing all named columns
    result = pd.DataFrame({k: [] for k in headers})
    
    #Get table data and append to dataframe
    table_data = dom('tbody tr')
    for i in range(len(table_data)):
        row = table_data[i]
        tds = row('td')
        cells = [tds[j].content for j in range(len(tds))]
        
        #Make table readable for user
        for k in range(len(cells)):
            if "<i " in str(cells[k]):
                cells[k] = extractfromi(cells[k])
            elif "<span" in str(cells[k]):
                cells[k] = extractfromspan(cells[k])
            elif "<a " in str(cells[k]):
                cells[k] = extractfroma(cells[k])
        
        result = result.append(pd.Series(cells, index=headers), ignore_index=True)
    
    return result

station_list = pd.DataFrame()
for u in url:
    station_list = station_list.append(getTable(u))
station_list = station_list.set_index('ID')

station_list
# Out:
#                     Status Uptime                   Country  \
# ID
# 2418                Online  100 %                    Angola
# 2766                Online   97 %                    Angola
# 2995                Online  100 %                 Australia
# 2502                Online  100 %                 Australia
# 2508                Online  100 %                 Australia
# 2740                Online  100 %                 Australia
# 2556                Online   99 %                 Australia
# 2637                Online   91 %                 Australia
# 2936                Online   99 %                 Australia
# 2465                Online   98 %                 Australia
# 2864                Online  100 %                 Australia
# 2234                Online  100 %                 Australia
# 2360                Online  100 %                 Australia
# 2070                Online  100 %                 Australia
# 2675                Online  100 %                 Australia
# 3292                Online   91 %                 Australia
# 2701                Online  100 %                 Australia
# 2520                Online  100 %                   Austria
# 2798                Online  100 %                   Austria
# 3258                Online   47 %                  Barbados
# 2145                Online  100 %                   Belgium
# 2713  Offline > 10 minutes   51 %                   Belgium
# 2265                Online  100 %                   Belgium
# 2515                Online  100 %                   Belgium
# 2292                Online  100 %                   Belgium
# 3249                Online   95 %                   Belgium
# 3359                Online   89 %                   Belgium
# 2404                Online  100 %                   Belgium
# 2724                Online   95 %                   Belgium
# 2300                Online  100 %                   Belgium
# ...                    ...    ...                       ...
# 2944                  Dead    0 %  United States of America
# 2891  Offline > 10 minutes    2 %  United States of America
# 3221                Online  100 %  United States of America
# 2349                Online   90 %  United States of America
# 2657  Offline > 10 minutes   64 %  United States of America
# 2727    Offline > 24 hours   18 %  United States of America
# 2056                Online  100 %  United States of America
# 2229  Offline > 10 minutes   43 %  United States of America
# 2247                Online  100 %  United States of America
# 2495                Online  100 %  United States of America
# 2277                Online  100 %  United States of America
# 2833                Online  100 %  United States of America
# 3342                Online   95 %  United States of America
# 2646                Online   99 %  United States of America
# 2184                Online  100 %  United States of America
# 2023                Online  100 %  United States of America
# 2035                Online  100 %  United States of America
# 3231                Online  100 %  United States of America
# 3380                Online    7 %  United States of America
# 2466                Online   97 %  United States of America
# 2650                Online   98 %  United States of America
# 2071                Online   93 %  United States of America
# 2048                Online   45 %  United States of America
# 2656                Online   71 %                   Unknown
# 3146  Offline > 10 minutes   35 %                   Unknown
# 2992                Online  100 %                   Unknown
# 2688    Offline > 24 hours   21 %                   Unknown
# 2389                Online  100 %                   Uruguay
# 3314                Online  100 %                  Viet Nam
# 2040                Online  100 %                  Viet Nam
#
#                       Location Ships Distinct              Source
# ID
# 2418                     Zaire    39       38                None
# 2766                     Zaire     9        9                None
# 2995                  Kingston    10        8                None
# 2502               Scarborough     4        0                None
# 2508             Port Stephens    27       10                None
# 2740                    Coogee    23        0                None
# 2556                  Franklin     5        5                None
# 2637                 Devonport     4        4                None
# 2936                 Kettering    14       12                None
# 2465                    Darwin    55       55                None
# 2864                Morayfield    24       20                None
# 2234    Mt Arthur (N.Tasmania)    12       12                None
# 2360              Port Hedland   130      126                None
# 2070           Nelson Bay, NSW    25        8                None
# 2675                    Sydney    20       20                None
# 3292        Oakleigh, Victoria     1        1             SARCNET
# 2701                  O'Connor    71       48                None
# 2520                    Vienna    11        0                None
# 2798                      Linz    45       45                None
# 3258                 St. James     6        6                None
# 2145                  Antwerp2   417       34  Tresco Engineering
# 2713                    Leuven     0        0                None
# 2265                   Antwerp   378        0    www.canaleye.com
# 2515                 Antwerpen   741       81    www.canaleye.com
# 2292                      Gent   380       69                None
# 3249                   Antwerp    81        0                None
# 3359                   Schoten    18        1                None
# 2404                    Bruges   116       36            dotOcean
# 2724                     Ghent     3        0                None
# 2300                   Schilde   236       23     www.vemasys.com
# ...                        ...   ...      ...                 ...
# 2944                   Seattle     0        0                None
# 2891                 Melbourne     0        0                None
# 3221           Mill Valley, CA    32        1                None
# 2349                  Portland    65       50                None
# 2657                     Niles     0        0                None
# 2727                Washingotn     0        0                None
# 2056               New Orleans   105      104                None
# 2229                  New York     0        0                None
# 2247        Hanover, Maryland     46       30                None
# 2495                Duluth, MN    13       13                None
# 2277     Dania Beach - Florida   208       21                None
# 2833                    Groton     7        0                None
# 3342             San Francisco    98        3                None
# 2646             Arkwright, NY     2        2                None
# 2184                  Beaufort    40       40                None
# 2023  Baltimore MD, Wilmington    28        8                None
# 2035                   Seattle   324       74         Shine Micro
# 3231    Baton Rouge, Louisiana    53       53                None
# 3380                   Brielle     2        2                None
# 2466                Callao, VA     1        1                None
# 2650        Sabine Pass, Texas   104        5                None
# 2071       Fort Lauderdale, Fl   441        0                None
# 2048              Adak, Alaska     6        6                None
# 2656                  Cagliari    21       21                None
# 3146                    At Sea     0        0             Sea Jay
# 2992                    At Sea    37        2                None
# 2688            Mobile Station     0        0                None
# 2389                Montevideo    30       30                None
# 3314                     Hanoi    45       45                None
# 2040                      HCMC    21       21                None
#
# [744 rows x 7 columns]

# %%
import geopandas as gpd

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world = world.rename(columns={'name': 'Country'})

world = world.set_index('Country')
world.plot()

# %%
def mapByDistinct(stations):
    """
    Function
    --------
    Maps each country by how many of its distint ships are active
    
    Parameters
    ----------
    stations: dataframe of each station on record
    
    Returns
    -------
    Nothing
    """
    stations = stations[(stations.Status == "Online") & (stations.Country != 'Unknown')]
    stations.Country = stations.Country.replace("Viet Nam", "Vietnam").replace("Saint Martin (FR)", "France").replace("Taiwan (Province of China)", "Taiwan").replace("Russian Federation", "Russia")
    stations = stations.set_index(['Country','Source'])
    distinct_total = stations.Distinct.astype(int).sum(level="Country")
    
    #append to world
    global world
    world["Ship_circulation_est"] = distinct_total
    
    #plot result
    result = world.plot(column='Ship_circulation_est', 
                        legend=True,
                        legend_kwds={'label': 'Active ships per country',
                                     'orientation': 'horizontal'},
                        missing_kwds={'color':'lightgrey'})
    plt.savefig('shipsPerCountry.png')
    
    return result

ships_per_Country = mapByDistinct(station_list)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
#Now less see the amount of active ships per 1000000 persons for each country
world["Ships_per_1e6"] = (world.Ship_circulation_est / world.pop_est) * 1e6


ships_per_1e6 = world.plot(column='Ships_per_1e6', 
                           legend=True,
                           legend_kwds={'label': 'Active ships relative to million persons',
                                        'orientation': 'horizontal'},
                           missing_kwds={'color': 'lightgray'})
plt.savefig('shipsPer1e6.png')

# %%
from scipy.special import erf
def GaussianProb():
    """
    Function
    --------
    Works out gaussian porobability that ship belongs to specific demographic. Adds to dataframe
    
    Parameters
    ----------
    None
    
    Returns
    -------
    None
    """
    cdf = lambda x, mu, sig: 0.5 * (1 + erf((x - mu) / (sig * np.sqrt(2))))
    
    global world
    world["CDF"] = cdf(world.Ship_circulation_est, world.Ship_circulation_est.mean(), world.Ship_circulation_est.std())
    
    #If NaN assume zero
    world.CDF = world.CDF.fillna(float(0))
    
GaussianProb()

# %%
ships_cdf = world.plot(column='CDF', 
                           legend=True,
                           legend_kwds={'label': 'Likleyhood active ship belongs to country',
                                        'orientation': 'horizontal'})
plt.savefig('shipsCDF.png')

# %%
ports = pd.DataFrame({'Country': station_list.Country, 'Location': station_list.Location}).drop_duplicates()

# %%
#We will have to find a way of adding geometric loction to each station
#First less add a column to ports labeled geometry and set each entry to None
ports["Longitude"] = [None for i in range(ports.shape[0])]
ports["Latitude"] = [None for i in range(ports.shape[0])]
cities = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))
ports
# Out:
#                        Country                  Location Longitude Latitude
# ID
# 2418                    Angola                     Zaire      None     None
# 2995                 Australia                  Kingston      None     None
# 2502                 Australia               Scarborough      None     None
# 2508                 Australia             Port Stephens      None     None
# 2740                 Australia                    Coogee      None     None
# 2556                 Australia                  Franklin      None     None
# 2637                 Australia                 Devonport      None     None
# 2936                 Australia                 Kettering      None     None
# 2465                 Australia                    Darwin      None     None
# 2864                 Australia                Morayfield      None     None
# 2234                 Australia    Mt Arthur (N.Tasmania)      None     None
# 2360                 Australia              Port Hedland      None     None
# 2070                 Australia           Nelson Bay, NSW      None     None
# 2675                 Australia                    Sydney      None     None
# 3292                 Australia        Oakleigh, Victoria      None     None
# 2701                 Australia                  O'Connor      None     None
# 2520                   Austria                    Vienna      None     None
# 2798                   Austria                      Linz      None     None
# 3258                  Barbados                 St. James      None     None
# 2145                   Belgium                  Antwerp2      None     None
# 2713                   Belgium                    Leuven      None     None
# 2265                   Belgium                   Antwerp      None     None
# 2515                   Belgium                 Antwerpen      None     None
# 2292                   Belgium                      Gent      None     None
# 3359                   Belgium                   Schoten      None     None
# 2404                   Belgium                    Bruges      None     None
# 2724                   Belgium                     Ghent      None     None
# 2300                   Belgium                   Schilde      None     None
# 2709                   Belgium   Watervliet, St Laureins      None     None
# 2061                   Belgium                    Ostend      None     None
# ...                        ...                       ...       ...      ...
# 3045  United States of America                  New York      None     None
# 3001  United States of America                  Brooklyn      None     None
# 2172  United States of America                Navarre FL      None     None
# 3253  United States of America      Berkeley, California      None     None
# 2638  United States of America            Baldwin Harbor      None     None
# 2891  United States of America                 Melbourne      None     None
# 3221  United States of America           Mill Valley, CA      None     None
# 2349  United States of America                  Portland      None     None
# 2657  United States of America                     Niles      None     None
# 2727  United States of America                Washingotn      None     None
# 2056  United States of America               New Orleans      None     None
# 2247  United States of America        Hanover, Maryland       None     None
# 2495  United States of America                Duluth, MN      None     None
# 2277  United States of America     Dania Beach - Florida      None     None
# 2833  United States of America                    Groton      None     None
# 2646  United States of America             Arkwright, NY      None     None
# 2184  United States of America                  Beaufort      None     None
# 2023  United States of America  Baltimore MD, Wilmington      None     None
# 3231  United States of America    Baton Rouge, Louisiana      None     None
# 3380  United States of America                   Brielle      None     None
# 2466  United States of America                Callao, VA      None     None
# 2650  United States of America        Sabine Pass, Texas      None     None
# 2071  United States of America       Fort Lauderdale, Fl      None     None
# 2048  United States of America              Adak, Alaska      None     None
# 2656                   Unknown                  Cagliari      None     None
# 3146                   Unknown                    At Sea      None     None
# 2688                   Unknown            Mobile Station      None     None
# 2389                   Uruguay                Montevideo      None     None
# 3314                  Viet Nam                     Hanoi      None     None
# 2040                  Viet Nam                      HCMC      None     None
#
# [586 rows x 4 columns]

# %%
import wikipedia as wiki
def getGeometry(station):
    """
    Function
    --------
    Gets geometric location for each port, by mining wikipedia.
    
    Parameters
    ----------
    station: Entry in dataframe ports
    
    Returns
    -------
    geometry: estimated location in float form
    """
    coords = None
    i = 0
    engine = wiki.search(station.Location + ', ' + station.Country)
    while i < len(engine):
        try:
            page = wiki.page(engine[i])
            coords = page.coordinates
            break
        except wiki.exceptions.DisambiguationError as dmbError:
            engine = wiki.search(station.Location + ', ' + station.Country + ', port')
        except:
            coords = None
        i = i + 1
    
    try:
        station.Longitude = float(coords[0])
        station.Latitude = float(coords[1])
    except:
        station.Longitude = float(np.nan)
        station.Latitude = float(np.nan)
        
    return station

j = 200
while j < 586:
    ports.iloc[j, :] = getGeometry(ports.iloc[j, :])
    j = j + 1

# %%
ports
# Out:
#                        Country                  Location Longitude Latitude
# ID
# 2418                    Angola                     Zaire  -6.26667  14.2333
# 2995                 Australia                  Kingston  -35.3156  149.144
# 2502                 Australia               Scarborough  -31.8942  115.764
# 2508                 Australia             Port Stephens    -32.75  151.917
# 2740                 Australia                    Coogee   -33.919  151.256
# 2556                 Australia                  Franklin  -33.6833  136.917
# 2637                 Australia                 Devonport  -41.1806  146.346
# 2936                 Australia                 Kettering  -43.1167  147.267
# 2465                 Australia                    Darwin  -12.4381  130.841
# 2864                 Australia                Morayfield  -27.1053  152.947
# 2234                 Australia    Mt Arthur (N.Tasmania)        -6       35
# 2360                 Australia              Port Hedland    -20.31  118.601
# 2070                 Australia           Nelson Bay, NSW    -32.75  152.167
# 2675                 Australia                    Sydney   -33.865  151.209
# 3292                 Australia        Oakleigh, Victoria   -37.913  145.102
# 2701                 Australia                  O'Connor  -35.2592  149.121
# 2520                   Austria                    Vienna        16      108
# 2798                   Austria                      Linz      48.3  14.2833
# 3258                  Barbados                 St. James   13.2167 -59.6167
# 2145                   Belgium                  Antwerp2   51.2178  4.40028
# 2713                   Belgium                    Leuven   50.8833      4.7
# 2265                   Belgium                   Antwerp   51.2178  4.40028
# 2515                   Belgium                 Antwerpen   51.2178  4.40028
# 2292                   Belgium                      Gent     51.05  3.73333
# 3359                   Belgium                   Schoten     51.25      4.5
# 2404                   Belgium                    Bruges   51.2167  3.23333
# 2724                   Belgium                     Ghent     51.05  3.73333
# 2300                   Belgium                   Schilde   51.2333  4.56667
# 2709                   Belgium   Watervliet, St Laureins       NaN      NaN
# 2061                   Belgium                    Ostend   51.2333  2.91667
# ...                        ...                       ...       ...      ...
# 3045  United States of America                  New York   40.7127  -74.006
# 3001  United States of America                  Brooklyn   40.7217 -73.9578
# 2172  United States of America                Navarre FL    30.401  -86.863
# 3253  United States of America      Berkeley, California        37     -120
# 2638  United States of America            Baldwin Harbor   40.6339 -73.6039
# 2891  United States of America                 Melbourne   28.1167 -80.6333
# 3221  United States of America           Mill Valley, CA   37.9061 -122.545
# 2349  United States of America                  Portland        40     -100
# 2657  United States of America                     Niles   42.0278   -87.81
# 2727  United States of America                Washingotn   38.9047 -77.0164
# 2056  United States of America               New Orleans     29.95   -90.08
# 2247  United States of America        Hanover, Maryland    39.1928 -76.7242
# 2495  United States of America                Duluth, MN   46.7869 -92.0982
# 2277  United States of America     Dania Beach - Florida   26.1935 -80.4767
# 2833  United States of America                    Groton   42.6111  -71.575
# 2646  United States of America             Arkwright, NY   42.4069 -79.2364
# 2184  United States of America                  Beaufort   32.4333 -80.6833
# 2023  United States of America  Baltimore MD, Wilmington        33      -88
# 3231  United States of America    Baton Rouge, Louisiana   30.4475 -91.1786
# 3380  United States of America                   Brielle     40.16 -74.4242
# 2466  United States of America                Callao, VA     37.86   -76.38
# 2650  United States of America        Sabine Pass, Texas   29.7264 -93.8633
# 2071  United States of America       Fort Lauderdale, Fl   26.1333   -80.15
# 2048  United States of America              Adak, Alaska    51.872 -176.636
# 2656                   Unknown                  Cagliari   39.2278  9.11111
# 3146                   Unknown                    At Sea   38.8764 -77.0722
# 2688                   Unknown            Mobile Station       NaN      NaN
# 2389                   Uruguay                Montevideo  -34.8836 -56.1819
# 3314                  Viet Nam                     Hanoi   21.0283  105.854
# 2040                  Viet Nam                      HCMC        16      108
#
# [586 rows x 4 columns]

# %%
#Drop nan items from Dataframe
ports = ports.dropna()
ports
# Out:
#                        Country                  Location Longitude Latitude
# ID
# 2418                    Angola                     Zaire  -6.26667  14.2333
# 2995                 Australia                  Kingston  -35.3156  149.144
# 2502                 Australia               Scarborough  -31.8942  115.764
# 2508                 Australia             Port Stephens    -32.75  151.917
# 2740                 Australia                    Coogee   -33.919  151.256
# 2556                 Australia                  Franklin  -33.6833  136.917
# 2637                 Australia                 Devonport  -41.1806  146.346
# 2936                 Australia                 Kettering  -43.1167  147.267
# 2465                 Australia                    Darwin  -12.4381  130.841
# 2864                 Australia                Morayfield  -27.1053  152.947
# 2234                 Australia    Mt Arthur (N.Tasmania)        -6       35
# 2360                 Australia              Port Hedland    -20.31  118.601
# 2070                 Australia           Nelson Bay, NSW    -32.75  152.167
# 2675                 Australia                    Sydney   -33.865  151.209
# 3292                 Australia        Oakleigh, Victoria   -37.913  145.102
# 2701                 Australia                  O'Connor  -35.2592  149.121
# 2520                   Austria                    Vienna        16      108
# 2798                   Austria                      Linz      48.3  14.2833
# 3258                  Barbados                 St. James   13.2167 -59.6167
# 2145                   Belgium                  Antwerp2   51.2178  4.40028
# 2713                   Belgium                    Leuven   50.8833      4.7
# 2265                   Belgium                   Antwerp   51.2178  4.40028
# 2515                   Belgium                 Antwerpen   51.2178  4.40028
# 2292                   Belgium                      Gent     51.05  3.73333
# 3359                   Belgium                   Schoten     51.25      4.5
# 2404                   Belgium                    Bruges   51.2167  3.23333
# 2724                   Belgium                     Ghent     51.05  3.73333
# 2300                   Belgium                   Schilde   51.2333  4.56667
# 2061                   Belgium                    Ostend   51.2333  2.91667
# 3283                   Belgium                 Diksmuide   51.0333      2.9
# ...                        ...                       ...       ...      ...
# 2523  United States of America           West Palm Beach    26.715 -80.0394
# 3045  United States of America                  New York   40.7127  -74.006
# 3001  United States of America                  Brooklyn   40.7217 -73.9578
# 2172  United States of America                Navarre FL    30.401  -86.863
# 3253  United States of America      Berkeley, California        37     -120
# 2638  United States of America            Baldwin Harbor   40.6339 -73.6039
# 2891  United States of America                 Melbourne   28.1167 -80.6333
# 3221  United States of America           Mill Valley, CA   37.9061 -122.545
# 2349  United States of America                  Portland        40     -100
# 2657  United States of America                     Niles   42.0278   -87.81
# 2727  United States of America                Washingotn   38.9047 -77.0164
# 2056  United States of America               New Orleans     29.95   -90.08
# 2247  United States of America        Hanover, Maryland    39.1928 -76.7242
# 2495  United States of America                Duluth, MN   46.7869 -92.0982
# 2277  United States of America     Dania Beach - Florida   26.1935 -80.4767
# 2833  United States of America                    Groton   42.6111  -71.575
# 2646  United States of America             Arkwright, NY   42.4069 -79.2364
# 2184  United States of America                  Beaufort   32.4333 -80.6833
# 2023  United States of America  Baltimore MD, Wilmington        33      -88
# 3231  United States of America    Baton Rouge, Louisiana   30.4475 -91.1786
# 3380  United States of America                   Brielle     40.16 -74.4242
# 2466  United States of America                Callao, VA     37.86   -76.38
# 2650  United States of America        Sabine Pass, Texas   29.7264 -93.8633
# 2071  United States of America       Fort Lauderdale, Fl   26.1333   -80.15
# 2048  United States of America              Adak, Alaska    51.872 -176.636
# 2656                   Unknown                  Cagliari   39.2278  9.11111
# 3146                   Unknown                    At Sea   38.8764 -77.0722
# 2389                   Uruguay                Montevideo  -34.8836 -56.1819
# 3314                  Viet Nam                     Hanoi   21.0283  105.854
# 2040                  Viet Nam                      HCMC        16      108
#
# [565 rows x 4 columns]

# %%
#Convert pors to geoDataFrame
geoPorts = gpd.GeoDataFrame(ports, geometry=gpd.points_from_xy(ports.Latitude, ports.Longitude))

# %%
#fig, ax = plt.subplots(figsize = (200, 200))
world.plot(column='CDF', 
           legend=True,
           legend_kwds={'label': 'Likleyhood active ship belongs to country',
                        'orientation': 'horizontal'})
geoPorts.plot()

# %%
def nearestStation(start, dest, location):
    """
    Function
    --------
    Function will take a coordinate pair, start 
    country and destination country, then return the nearest 
    station. Assume this is in the case of a lost and 
    stranded ship that is in need of finding its way back. We 
    will try to find this through checking the 2 norm.
    
    Parameters
    ----------
    start: Country the ship left
    dest: Country the ship wants to get to
    location: Coordinates of ship
    
    Returns
    -------
    Station: Location the ship needs to go to to get back on 
    course.
    """
    
    global world, geoPorts
    origin = world[world.index == start].geometry.bounds
    end = world[world.index == dest].geometry.bounds
    
    #Assume longest route to get vector direction in unit form
    vector = {'x': end.maxx[0] - origin.minx[0], 'y': end.maxy[0] - origin.miny[0]}
    vector = {'x': vector['x'] / np.sqrt(pow(vector['x'], 2) + pow(vector['y'], 2)), 
          'y': vector['y'] / np.sqrt(pow(vector['x'], 2) + pow(vector['y'], 2))}
    
    locV = {'x': location[0], 'y': location[0]}
    
    station = geoPorts.iloc[0, :]
    #First try and find if there are any stations between location and destination
    possibleStations = geoPorts[(geoPorts.Longitude < min(end.maxx[0], location[0])) & 
                                (geoPorts.Longitude > max(end.maxx[0], location[0])) &
                                (geoPorts.Latitude < min(end.maxy[0], location[0])) &
                                (geoPorts.Latitude > max(end.maxy[0], location[0]))]
    #If empty check any towards start point
    if possibleStations.shape[0] == 0:
        possibleStations = geoPorts[(geoPorts.Longitude > min(origin.maxx[0], location[0])) & 
                                    (geoPorts.Longitude < max(origin.maxx[0], location[0])) &
                                    (geoPorts.Latitude < min(origin.maxy[0], location[0])) &
                                    (geoPorts.Latitude < max(origin.maxy[0], location[0]))]
        if possibleStations.shape[0] == 0:
            possibleStations = geoPorts
            
    #Now get distance between each station and location
    possibleStations["distance"] = np.power(np.power(np.abs(possibleStations.Longitude - location[0]), 2) + 
                                           np.power(np.abs(possibleStations.Latitude - location[1]), 2), 1/2)
    
    ps = pd.DataFrame(possibleStations)
    
    #find entry with minimum distance and return
    station = ps[ps.distance == ps.distance.min()]
    
    return station

# %%
nearestStation('Australia', 'Angola', (75, -50))
# Out:
#         Country Location Longitude Latitude                    geometry  \
# ID
# 2075  Greenland     Nuuk   64.1814 -51.6942  POINT (-51.69417 64.18139)
#
#      distance
# ID
# 2075  10.9505
